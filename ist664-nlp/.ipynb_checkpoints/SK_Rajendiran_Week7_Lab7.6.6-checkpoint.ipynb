# %% [markdown]
# Name: Sathish Kumar Rajendiran
# Chapter :  Discourse and Dialogue
# Date: 11/14/2020
# Week: 7

# %%
#import libraries

# standard library
import os
import sys
from datetime import datetime
import time

# csv, xls, pandas & json
import pandas as pd
import json
import csv
import xlrd

# Language Processing
import nltk
from nltk import FreqDist
# import wordnet and shorten its name to wn
from nltk.corpus import wordnet as wn

# web requests
from urllib import request


##  Regular Expression to match non-alphabetic characters
import re

os.getcwd()
# Out:
# '/Users/sathishrajendiran/ist664-nlp'

# %%
# define a feature extraction function for each name
def gender_features(word):
    return{'last_letter': word[-1]}

print(gender_features('Shrek'))
# Out:
# {'last_letter': 'k'}

# %%
# resource for male and female first names
from nltk.corpus import names
print(names.words('male.txt')[:20])
# Out:
# ['Aamir', 'Aaron', 'Abbey', 'Abbie', 'Abbot', 'Abbott', 'Abby', 'Abdel', 'Abdul', 'Abdulkarim', 'Abdullah', 'Abe', 'Abel', 'Abelard', 'Abner', 'Abraham', 'Abram', 'Ace', 'Adair', 'Adam']

# %%
print(names.words('female.txt')[:20])
# Out:
# ['Abagael', 'Abagail', 'Abbe', 'Abbey', 'Abbi', 'Abbie', 'Abby', 'Abigael', 'Abigail', 'Abigale', 'Abra', 'Acacia', 'Ada', 'Adah', 'Adaline', 'Adara', 'Addie', 'Addis', 'Adel', 'Adela']

# %%
# make list of male and female names paired with gender
namesgender = ([(name, 'male') for name in names.words('male.txt')] +
          [(name, 'female') for name in names.words('female.txt')])
print(len(namesgender))
# Out:
# 7944

# %%
print(namesgender[:20])
# Out:
# [('Aamir', 'male'), ('Aaron', 'male'), ('Abbey', 'male'), ('Abbie', 'male'), ('Abbot', 'male'), ('Abbott', 'male'), ('Abby', 'male'), ('Abdel', 'male'), ('Abdul', 'male'), ('Abdulkarim', 'male'), ('Abdullah', 'male'), ('Abe', 'male'), ('Abel', 'male'), ('Abelard', 'male'), ('Abner', 'male'), ('Abraham', 'male'), ('Abram', 'male'), ('Ace', 'male'), ('Adair', 'male'), ('Adam', 'male')]

# %%
print(namesgender[7924:])
# Out:
# [('Zena', 'female'), ('Zenia', 'female'), ('Zia', 'female'), ('Zilvia', 'female'), ('Zita', 'female'), ('Zitella', 'female'), ('Zoe', 'female'), ('Zola', 'female'), ('Zonda', 'female'), ('Zondra', 'female'), ('Zonnya', 'female'), ('Zora', 'female'), ('Zorah', 'female'), ('Zorana', 'female'), ('Zorina', 'female'), ('Zorine', 'female'), ('Zsa Zsa', 'female'), ('Zsazsa', 'female'), ('Zulema', 'female'), ('Zuzana', 'female')]

# %%
# put the list into random order
import random
random.shuffle(namesgender)
print(namesgender[:20])
# Out:
# [('Randi', 'male'), ('Nerita', 'female'), ('Mischa', 'male'), ('Tam', 'male'), ('Odysseus', 'male'), ('Arvy', 'male'), ('Ivory', 'female'), ('Horatia', 'female'), ('Isaiah', 'male'), ('Grant', 'male'), ('Danit', 'female'), ('Annabel', 'female'), ('Adolphus', 'male'), ('Kelley', 'male'), ('Silvie', 'female'), ('Bea', 'female'), ('Rudy', 'male'), ('Veronique', 'female'), ('Willard', 'male'), ('Hersh', 'male')]

# %%
# separate the names into training and test
train_names = namesgender[500:]
test_names = namesgender[:500]

# %%
# use our features to train a classify and test on the development test set
train_set = [(gender_features(n), g) for (n, g) in train_names]
test_set = [(gender_features(n), g) for (n, g) in test_names]
print(train_set[:20])
# Out:
# [({'last_letter': 'a'}, 'female'), ({'last_letter': 'e'}, 'female'), ({'last_letter': 'n'}, 'male'), ({'last_letter': 'm'}, 'male'), ({'last_letter': 'n'}, 'male'), ({'last_letter': 'e'}, 'female'), ({'last_letter': 'e'}, 'male'), ({'last_letter': 'd'}, 'female'), ({'last_letter': 't'}, 'male'), ({'last_letter': 'a'}, 'female'), ({'last_letter': 'i'}, 'female'), ({'last_letter': 'a'}, 'female'), ({'last_letter': 'n'}, 'male'), ({'last_letter': 'y'}, 'male'), ({'last_letter': 'a'}, 'female'), ({'last_letter': 'k'}, 'male'), ({'last_letter': 'y'}, 'male'), ({'last_letter': 'e'}, 'female'), ({'last_letter': 'a'}, 'female'), ({'last_letter': 'y'}, 'female')]

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
classifier = nltk.NaiveBayesClassifier.train(train_set)

# %%
# classify new instances
print(classifier.classify(gender_features('Neo')))
print(classifier.classify(gender_features('Trinity')))
# Out:
# male
# female

# %% [markdown]
# We can the compute the accuracy of the classifier on the test set.
# The accuracy function for each classifier:
# * first removes the gender labels from the test set,
# * runs the classifier on each name in the test set to get a predicted gender, and
# * compares the predicted gender with each actual gender from the test set to get the evaluation score.
#
# In this case, it just produces an accuracy score, instead of precision and recall.

# %%
# classify accuracy function runs the classifier on the test set and reports
#   comparisons between predicted labels and actual/gold labels
print(nltk.classify.accuracy(classifier, test_set))
# Out:
# 0.746

# %%
# this function available for naive bayes classifiers
print(classifier.show_most_informative_features(20))
# Out:
# Most Informative Features
#              last_letter = 'a'            female : male   =     38.5 : 1.0
#              last_letter = 'k'              male : female =     30.8 : 1.0
#              last_letter = 'f'              male : female =     16.0 : 1.0
#              last_letter = 'v'              male : female =     15.3 : 1.0
#              last_letter = 'p'              male : female =     11.9 : 1.0
#              last_letter = 'd'              male : female =      9.8 : 1.0
#              last_letter = 'm'              male : female =      9.5 : 1.0
#              last_letter = 'o'              male : female =      8.8 : 1.0
#              last_letter = 'r'              male : female =      7.0 : 1.0
#              last_letter = 'w'              male : female =      5.4 : 1.0
#              last_letter = 'g'              male : female =      5.3 : 1.0
#              last_letter = 's'              male : female =      4.1 : 1.0
#              last_letter = 't'              male : female =      4.0 : 1.0
#              last_letter = 'u'              male : female =      4.0 : 1.0
#              last_letter = 'j'              male : female =      4.0 : 1.0
#              last_letter = 'z'              male : female =      4.0 : 1.0
#              last_letter = 'b'              male : female =      3.9 : 1.0
#              last_letter = 'i'            female : male   =      3.7 : 1.0
#              last_letter = 'n'              male : female =      2.2 : 1.0
#              last_letter = 'e'            female : male   =      1.8 : 1.0
# None

# %%
# define a function that will compare the classifier labels with the gold standard labels
def geterrors(test):
    errors = []
    for (name, tag) in test:
        guess = classifier.classify(gender_features(name))
        if guess != tag:
            errors.append( (tag, guess, name) )
    return errors

# %%
errors = geterrors(test_names)
print(len(errors))
# Out:
# 127

# %%
# define a function to print the errors
def printerrors(errors):
    for (tag, guess, name) in sorted(errors):
        print('correct={:<8s} guess={:<8s} name={:<30s}'.format(tag, guess, name))

printerrors(errors)
# Out:
# correct=female   guess=male     name=Ailyn
# correct=female   guess=male     name=Allys
# correct=female   guess=male     name=Arden
# correct=female   guess=male     name=Arlen
# correct=female   guess=male     name=Arlyn
# correct=female   guess=male     name=Brenn
# correct=female   guess=male     name=Brynn
# correct=female   guess=male     name=Charleen
# correct=female   guess=male     name=Charmian
# correct=female   guess=male     name=Charmion
# correct=female   guess=male     name=Christan
# correct=female   guess=male     name=Cloris
# correct=female   guess=male     name=Colleen
# correct=female   guess=male     name=Coralyn
# correct=female   guess=male     name=Danit
# correct=female   guess=male     name=Deb
# correct=female   guess=male     name=Doralin
# correct=female   guess=male     name=Elizabet
# correct=female   guess=male     name=Ethelind
# correct=female   guess=male     name=Evelyn
# correct=female   guess=male     name=Flower
# correct=female   guess=male     name=Gennifer
# correct=female   guess=male     name=Gillian
# correct=female   guess=male     name=Gladis
# correct=female   guess=male     name=Heather
# correct=female   guess=male     name=Honor
# correct=female   guess=male     name=Jaquelin
# correct=female   guess=male     name=Jessalin
# correct=female   guess=male     name=Jocelyn
# correct=female   guess=male     name=Juliann
# correct=female   guess=male     name=Karmen
# correct=female   guess=male     name=Kirstyn
# correct=female   guess=male     name=Koo
# correct=female   guess=male     name=Kristen
# correct=female   guess=male     name=Lou
# correct=female   guess=male     name=Lynnett
# correct=female   guess=male     name=Margalo
# correct=female   guess=male     name=Marget
# correct=female   guess=male     name=Marit
# correct=female   guess=male     name=Milissent
# correct=female   guess=male     name=Miriam
# correct=female   guess=male     name=Peg
# correct=female   guess=male     name=Pegeen
# correct=female   guess=male     name=Pru
# correct=female   guess=male     name=Quentin
# correct=female   guess=male     name=Rhianon
# correct=female   guess=male     name=Rosamond
# correct=female   guess=male     name=Shannen
# correct=female   guess=male     name=Suzan
# correct=female   guess=male     name=Tatum
# correct=female   guess=male     name=Terri-Jo
# correct=female   guess=male     name=Vin
# correct=female   guess=male     name=Viv
# correct=female   guess=male     name=Wallis
# correct=female   guess=male     name=Wynn
# correct=female   guess=male     name=Yoshiko
# correct=male     guess=female   name=Abe
# correct=male     guess=female   name=Adolphe
# correct=male     guess=female   name=Arvy
# correct=male     guess=female   name=Avi
# correct=male     guess=female   name=Bela
# correct=male     guess=female   name=Berkie
# correct=male     guess=female   name=Binky
# correct=male     guess=female   name=Cal
# correct=male     guess=female   name=Casey
# correct=male     guess=female   name=Chaunce
# correct=male     guess=female   name=Clarke
# correct=male     guess=female   name=Donnie
# correct=male     guess=female   name=Eli
# correct=male     guess=female   name=Erl
# correct=male     guess=female   name=Fonzie
# correct=male     guess=female   name=Hall
# correct=male     guess=female   name=Haskel
# correct=male     guess=female   name=Helmuth
# correct=male     guess=female   name=Hersh
# correct=male     guess=female   name=Hiralal
# correct=male     guess=female   name=Ike
# correct=male     guess=female   name=Ikey
# correct=male     guess=female   name=Immanuel
# correct=male     guess=female   name=Isa
# correct=male     guess=female   name=Isaiah
# correct=male     guess=female   name=Izzy
# correct=male     guess=female   name=Jeffry
# correct=male     guess=female   name=Jermaine
# correct=male     guess=female   name=Jessie
# correct=male     guess=female   name=Keefe
# correct=male     guess=female   name=Kelley
# correct=male     guess=female   name=Kelsey
# correct=male     guess=female   name=Kingsley
# correct=male     guess=female   name=Lennie
# correct=male     guess=female   name=Lenny
# correct=male     guess=female   name=Lindsay
# correct=male     guess=female   name=Marlowe
# correct=male     guess=female   name=Marshal
# correct=male     guess=female   name=Maxwell
# correct=male     guess=female   name=Michael
# correct=male     guess=female   name=Mischa
# correct=male     guess=female   name=Morry
# correct=male     guess=female   name=Nathanael
# correct=male     guess=female   name=Nathanil
# correct=male     guess=female   name=Neall
# correct=male     guess=female   name=Noe
# correct=male     guess=female   name=Noel
# correct=male     guess=female   name=Olle
# correct=male     guess=female   name=Parsifal
# correct=male     guess=female   name=Pascal
# correct=male     guess=female   name=Ramsey
# correct=male     guess=female   name=Randi
# correct=male     guess=female   name=Ray
# correct=male     guess=female   name=Rudy
# correct=male     guess=female   name=Sascha
# correct=male     guess=female   name=Seth
# correct=male     guess=female   name=Skell
# correct=male     guess=female   name=Solly
# correct=male     guess=female   name=Spence
# correct=male     guess=female   name=Stanleigh
# correct=male     guess=female   name=Tally
# correct=male     guess=female   name=Tony
# correct=male     guess=female   name=Torrance
# correct=male     guess=female   name=Tracie
# correct=male     guess=female   name=Udale
# correct=male     guess=female   name=Uriah
# correct=male     guess=female   name=Virge
# correct=male     guess=female   name=Vite
# correct=male     guess=female   name=Whitney
# correct=male     guess=female   name=Winny
# correct=male     guess=female   name=Zollie

# %%
## classify part of speech based on sentence context
from nltk.corpus import brown

# %%
# define features for the "i"th word in the sentence, including three types of suffix 
#     and one pre-word
# the pos features function takes the sentence of untagged words and the index of a word i
#   it creates features for word i, including the previous word i-1
def pos_features(sentence, i):    
    features = {"suffix(1)": sentence[i][-1:],
                 "suffix(2)": sentence[i][-2:],
                 "suffix(3)": sentence[i][-3:]}
    if i == 0:
        features["prev-word"] = "<START>"
    else:
        features["prev-word"] = sentence[i-1]
    return features

# %%
# look at features of a specific word in a specific sentence
# first sentence of brown corpus
sentence0 = brown.sents()[0]
print(sentence0)
# Out:
# ['The', 'Fulton', 'County', 'Grand', 'Jury', 'said', 'Friday', 'an', 'investigation', 'of', "Atlanta's", 'recent', 'primary', 'election', 'produced', '``', 'no', 'evidence', "''", 'that', 'any', 'irregularities', 'took', 'place', '.']

# %%
# word 8 of sentence 0
print(sentence0[8])
# Out:
# investigation

# %%
# pos features of the word 8 
print(pos_features(sentence0, 8))
# Out:
# {'suffix(1)': 'n', 'suffix(2)': 'on', 'suffix(3)': 'ion', 'prev-word': 'an'}

# %%
# get the POS tagged sentences with categories of news
tagged_sents = brown.tagged_sents(categories='news')
tag_sent0 = tagged_sents[0]
tag_sent0
# Out:
# [('The', 'AT'),
#  ('Fulton', 'NP-TL'),
#  ('County', 'NN-TL'),
#  ('Grand', 'JJ-TL'),
#  ('Jury', 'NN-TL'),
#  ('said', 'VBD'),
#  ('Friday', 'NR'),
#  ('an', 'AT'),
#  ('investigation', 'NN'),
#  ('of', 'IN'),
#  ("Atlanta's", 'NP$'),
#  ('recent', 'JJ'),
#  ('primary', 'NN'),
#  ('election', 'NN'),
#  ('produced', 'VBD'),
#  ('``', '``'),
#  ('no', 'AT'),
#  ('evidence', 'NN'),
#  ("''", "''"),
#  ('that', 'CS'),
#  ('any', 'DTI'),
#  ('irregularities', 'NNS'),
#  ('took', 'VBD'),
#  ('place', 'NN'),
#  ('.', '.')]

# %%
# the function nltk.tag.untag will take the tags off
nltk.tag.untag(tag_sent0)
# Out:
# ['The',
#  'Fulton',
#  'County',
#  'Grand',
#  'Jury',
#  'said',
#  'Friday',
#  'an',
#  'investigation',
#  'of',
#  "Atlanta's",
#  'recent',
#  'primary',
#  'election',
#  'produced',
#  '``',
#  'no',
#  'evidence',
#  "''",
#  'that',
#  'any',
#  'irregularities',
#  'took',
#  'place',
#  '.']

# %%
# the python enumerate function generates an index number for each item in a list
for i,(word,tag) in enumerate(tag_sent0):
    print (i, word, tag)
# Out:
# 0 The AT
# 1 Fulton NP-TL
# 2 County NN-TL
# 3 Grand JJ-TL
# 4 Jury NN-TL
# 5 said VBD
# 6 Friday NR
# 7 an AT
# 8 investigation NN
# 9 of IN
# 10 Atlanta's NP$
# 11 recent JJ
# 12 primary NN
# 13 election NN
# 14 produced VBD
# 15 `` ``
# 16 no AT
# 17 evidence NN
# 18 '' ''
# 19 that CS
# 20 any DTI
# 21 irregularities NNS
# 22 took VBD
# 23 place NN
# 24 . .

# %%
# get feature sets of words appearing in the corpus, from untagged sentences.
# and then get their tags from corresponding tagged sentence
# use the Python function enumerate to pair the index numbers with sentence words 
#   for the pos features function
featuresets = []
for tagged_sent in tagged_sents:
    untagged_sent = nltk.tag.untag(tagged_sent)
    for i, (word, tag) in enumerate(tagged_sent):
        featuresets.append( (pos_features(untagged_sent, i), tag) )

# %%
# look at the feature sets of the first 10 words
for f in featuresets[:10]:
    print (f)
# Out:
# ({'suffix(1)': 'e', 'suffix(2)': 'he', 'suffix(3)': 'The', 'prev-word': '<START>'}, 'AT')
# ({'suffix(1)': 'n', 'suffix(2)': 'on', 'suffix(3)': 'ton', 'prev-word': 'The'}, 'NP-TL')
# ({'suffix(1)': 'y', 'suffix(2)': 'ty', 'suffix(3)': 'nty', 'prev-word': 'Fulton'}, 'NN-TL')
# ({'suffix(1)': 'd', 'suffix(2)': 'nd', 'suffix(3)': 'and', 'prev-word': 'County'}, 'JJ-TL')
# ({'suffix(1)': 'y', 'suffix(2)': 'ry', 'suffix(3)': 'ury', 'prev-word': 'Grand'}, 'NN-TL')
# ({'suffix(1)': 'd', 'suffix(2)': 'id', 'suffix(3)': 'aid', 'prev-word': 'Jury'}, 'VBD')
# ({'suffix(1)': 'y', 'suffix(2)': 'ay', 'suffix(3)': 'day', 'prev-word': 'said'}, 'NR')
# ({'suffix(1)': 'n', 'suffix(2)': 'an', 'suffix(3)': 'an', 'prev-word': 'Friday'}, 'AT')
# ({'suffix(1)': 'n', 'suffix(2)': 'on', 'suffix(3)': 'ion', 'prev-word': 'an'}, 'NN')
# ({'suffix(1)': 'f', 'suffix(2)': 'of', 'suffix(3)': 'of', 'prev-word': 'investigation'}, 'IN')

# %%
# using naive Bayesian as classifier
# split data into a training set and a test set, using a 90%/10% split
size = int(len(featuresets) * 0.1)
train_set, test_set = featuresets[size:], featuresets[:size]
print(len(train_set))
print(len(test_set))
# Out:
# 90499
# 10055

# %%
# train classifier on the training set
classifier = nltk.NaiveBayesClassifier.train(train_set)

# evaluate the accuracy (this will take a little while)
print(nltk.classify.accuracy(classifier, test_set))
# the result is reasonable for features without the previous tag
# Out:
# 0.7891596220785678

# %%
### classify documents based on keywords
from nltk.corpus import movie_reviews
import random

# movie reviews are labeled either positive or negative (by human annotators)
print(movie_reviews.categories())
# Out:
# ['neg', 'pos']

# %%
# for each document in movie_reviews, get its words and category (positive/negative)
documents = [(list(movie_reviews.words(fileid)), category)
              for category in movie_reviews.categories()
              for fileid in movie_reviews.fileids(category)]
print(len(documents))
# Out:
# 2000

# %%
random.shuffle(documents)
# look at the first document - consists of a list of all the words in the review
# followed by the category
print(documents[0])
# Out:
# (['summary', 'five', 'liberal', 'iowa', 'graduate', 'students', 'share', 'a', 'house', 'and', 'carry', 'on', 'a', 'tradition', 'of', 'a', 'large', 'sunday', 'dinner', '.', 'for', 'a', 'year', 'now', 'they', 'have', 'been', 'inviting', 'a', 'guest', 'for', 'dinner', 'and', 'discussion', '.', 'on', 'this', 'occasion', 'one', 'of', 'the', 'roommates', ',', 'pete', '(', 'ron', 'eldard', ')', ',', 'brings', 'home', 'a', 'stranger', 'who', 'picked', 'him', 'up', 'when', 'his', 'car', 'broke', 'down', '.', 'the', 'stranger', 'is', 'zack', '(', 'bill', 'paxton', ')', 'who', 'appears', 'like', 'a', 'decent', 'enough', 'good', 'samaritan', '.', 'nothing', 'could', 'be', 'further', 'from', 'the', 'truth', '.', 'after', 'some', 'dinner', 'conversation', 'it', 'appears', 'that', 'zack', 'is', ',', 'among', 'other', 'things', ',', 'a', 'racist', '"', 'you', 'know', 'my', 'grandfather', 'once', 'said', 'that', 'if', 'he', 'knew', 'you', 'coloreds', 'were', 'going', 'to', 'be', 'so', 'much', 'trouble', 'we', "'", 'd', 'have', 'picked', 'the', 'damn', 'cotton', 'ourselves', '"', ',', 'and', 'an', 'anti', '-', 'semite', '.', 'an', 'argument', 'escalates', 'at', 'the', 'dinner', 'table', 'and', 'leads', 'to', 'violence', '.', 'after', 'zack', 'assaults', 'marc', '(', 'jonathan', 'penner', ')', 'and', 'pete', ',', 'zack', 'is', 'killed', '.', 'the', 'roommates', 'are', 'at', 'odds', 'with', 'what', 'to', 'do', '.', 'marc', ',', 'pete', 'and', 'paulie', '(', 'annabeth', 'gish', ')', 'immediately', 'wish', 'to', 'call', 'the', 'police', '.', 'luke', '(', 'courtney', 'b', '.', 'vance', ')', 'and', 'jude', '(', 'cameron', 'diaz', ')', 'suggest', 'something', 'different', '.', 'after', 'more', 'discussion', 'they', 'agree', 'to', 'dispose', 'of', 'the', 'body', 'and', 'cover', 'it', 'up', '.', 'they', 'do', 'not', 'want', 'to', 'be', 'sent', 'to', 'jail', 'for', 'what', 'they', 'feel', 'was', 'a', 'justifiable', 'homicide', '.', 'when', 'it', 'is', 'done', 'the', 'roommates', 'realize', 'that', 'it', 'was', 'easier', 'than', 'they', 'thought', '.', 'so', 'easy', 'in', 'fact', 'that', 'they', 'decide', 'that', 'every', 'sunday', 'their', 'dinner', 'guest', 'would', 'be', 'someone', 'who', 'opposes', 'of', 'their', 'views', '.', 'if', 'they', 'all', 'agree', 'that', 'the', 'guest', 'deserves', 'to', 'die', ',', 'they', 'will', 'poison', 'them', 'and', 'bury', 'them', 'in', 'the', 'back', 'yard', '.', 'the', 'back', 'yard', 'fills', 'up', 'rather', 'quickly', ',', 'its', "'", 'victims', 'including', '(', 'among', 'others', ')', 'a', 'right', 'to', 'life', 'extremist', ',', 'an', 'anti', '-', 'environmentalist', 'and', 'a', 'homophobe', '.', 'by', 'the', 'time', 'the', 'roommates', 'get', 'to', 'their', 'tenth', 'victim', 'they', 'begin', 'to', 'question', 'their', 'methods', '.', 'are', 'they', 'giving', 'the', 'guests', 'a', 'chance', '?', 'are', 'they', 'even', 'giving', 'them', 'good', 'food', 'anymore', '?', 'this', 'film', 'is', 'what', 'i', 'like', 'to', 'call', 'a', '"', 'hidden', 'treasure', '"', '.', 'this', 'film', 'is', 'such', 'a', 'pleasant', 'surprise', '.', 'a', 'well', 'written', ',', 'devilish', 'satire', 'that', 'is', 'funny', ',', 'sexy', 'and', 'original', '.', 'this', 'film', 'should', 'be', 'a', 'hit', ',', 'but', 'i', 'guess', 'the', 'fact', 'that', 'it', 'apparently', 'had', 'no', 'marketing', 'wouldn', "'", 't', 'give', 'it', 'much', 'of', 'a', 'chance', '.', 'i', 'had', 'never', 'heard', 'of', 'it', 'until', 'i', 'saw', 'a', 'copy', 'at', 'my', 'video', 'store', '.', 'stacy', 'title', 'does', 'a', 'wonderful', 'job', 'directing', '.', 'she', 'somehow', 'finds', 'the', 'time', 'to', 'give', 'all', 'of', 'the', 'characters', 'enough', 'screen', 'time', 'to', 'develop', 'a', 'distinct', 'personality', '.', '>', 'from', 'the', 'five', 'members', 'of', 'the', 'house', 'to', 'other', 'key', 'characters', 'including', 'sheriff', 'stanley', '(', 'nora', 'dunn', ')', ',', 'the', 'local', 'law', 'closing', 'in', 'on', 'the', 'truth', ',', ...

# %%
## use words from all documents to define the word vector for features
# get all words from all movie_reviews and put into a frequency distribution
all_words = nltk.FreqDist(w.lower() for w in movie_reviews.words())
print(len(all_words))
# Out:
# 39768

# %%
# get the 2000 most frequently appearing keywords in the corpus
word_items = all_words.most_common(10000)
word_features = [word for (word, freq) in word_items]   # just the words

# look at the first 100 words
print(word_features[:100])
# Out:
# [',', 'the', '.', 'a', 'and', 'of', 'to', "'", 'is', 'in', 's', '"', 'it', 'that', '-', ')', '(', 'as', 'with', 'for', 'his', 'this', 'film', 'i', 'he', 'but', 'on', 'are', 't', 'by', 'be', 'one', 'movie', 'an', 'who', 'not', 'you', 'from', 'at', 'was', 'have', 'they', 'has', 'her', 'all', '?', 'there', 'like', 'so', 'out', 'about', 'up', 'more', 'what', 'when', 'which', 'or', 'she', 'their', ':', 'some', 'just', 'can', 'if', 'we', 'him', 'into', 'even', 'only', 'than', 'no', 'good', 'time', 'most', 'its', 'will', 'story', 'would', 'been', 'much', 'character', 'also', 'get', 'other', 'do', 'two', 'well', 'them', 'very', 'characters', ';', 'first', '--', 'after', 'see', '!', 'way', 'because', 'make', 'life']

# %%
# define features (keywords) of a document
# each feature is 'contains(keyword)' and is true or false depending
# on whether that keyword is in the document
def document_features(document, word_features):
    document_words = set(document)
    features = {}
    for word in word_features:
        features['V_%s' % word] = (word in document_words)
    return features

# get features sets for a document, including keyword features and category feature
featuresets = [(document_features(d, word_features), c) for (d,c) in documents]

# the feature sets are 2000 words long - so this is optional
print(featuresets[0])
# Out:
# ({'V_,': True, 'V_the': True, 'V_.': True, 'V_a': True, 'V_and': True, 'V_of': True, 'V_to': True, "V_'": True, 'V_is': True, 'V_in': True, 'V_s': False, 'V_"': True, 'V_it': True, 'V_that': True, 'V_-': True, 'V_)': True, 'V_(': True, 'V_as': True, 'V_with': True, 'V_for': True, 'V_his': True, 'V_this': True, 'V_film': True, 'V_i': True, 'V_he': True, 'V_but': True, 'V_on': True, 'V_are': True, 'V_t': True, 'V_by': True, 'V_be': True, 'V_one': True, 'V_movie': True, 'V_an': True, 'V_who': True, 'V_not': True, 'V_you': True, 'V_from': True, 'V_at': True, 'V_was': True, 'V_have': True, 'V_they': True, 'V_has': False, 'V_her': False, 'V_all': True, 'V_?': True, 'V_there': False, 'V_like': True, 'V_so': True, 'V_out': True, 'V_about': False, 'V_up': True, 'V_more': True, 'V_what': True, 'V_when': True, 'V_which': False, 'V_or': False, 'V_she': True, 'V_their': True, 'V_:': True, 'V_some': True, 'V_just': True, 'V_can': False, 'V_if': True, 'V_we': True, 'V_him': True, 'V_into': False, 'V_even': True, 'V_only': False, 'V_than': True, 'V_no': True, 'V_good': True, 'V_time': True, 'V_most': False, 'V_its': True, 'V_will': True, 'V_story': False, 'V_would': True, 'V_been': True, 'V_much': True, 'V_character': False, 'V_also': True, 'V_get': True, 'V_other': True, 'V_do': True, 'V_two': False, 'V_well': True, 'V_them': True, 'V_very': False, 'V_characters': True, 'V_;': False, 'V_first': True, 'V_--': False, 'V_after': True, 'V_see': False, 'V_!': False, 'V_way': True, 'V_because': True, 'V_make': False, 'V_life': True, 'V_off': False, 'V_too': False, 'V_any': False, 'V_does': True, 'V_really': False, 'V_had': True, 'V_while': True, 'V_films': True, 'V_how': False, 'V_plot': False, 'V_little': False, 'V_where': False, 'V_people': True, 'V_over': False, 'V_could': True, 'V_then': False, 'V_me': True, 'V_scene': False, 'V_man': False, 'V_bad': False, 'V_my': True, 'V_never': True, 'V_being': False, 'V_best': True, 'V_these': False, 'V_don': False, 'V_new': False, 'V_doesn': False, 'V_scenes': False, 'V_many': True, 'V_director': False, 'V_such': True, 'V_know': True, 'V_were': True, 'V_movies': False, 'V_through': False, 'V_here': False, 'V_action': False, 'V_great': False, 'V_re': False, 'V_another': False, 'V_love': False, 'V_go': False, 'V_made': False, 'V_us': False, 'V_big': True, 'V_end': False, 'V_something': True, 'V_back': True, 'V_*': False, 'V_still': False, 'V_world': False, 'V_seems': False, 'V_work': False, 'V_those': False, 'V_makes': False, 'V_now': True, 'V_before': False, 'V_however': False, 'V_between': False, 'V_few': False, 'V_/': False, 'V_down': True, 'V_every': True, 'V_though': False, 'V_better': False, 'V_real': False, 'V_audience': False, 'V_enough': True, 'V_seen': True, 'V_take': False, 'V_around': False, 'V_both': False, 'V_going': True, 'V_year': True, 'V_performance': True, 'V_why': False, 'V_should': True, 'V_role': False, 'V_isn': False, 'V_same': False, 'V_old': False, 'V_gets': False, 'V_your': False, 'V_may': True, 'V_things': True, 'V_think': True, 'V_years': False, 'V_last': False, 'V_comedy': False, 'V_funny': True, 'V_actually': False, 'V_ve': False, 'V_long': False, 'V_look': False, 'V_almost': False, 'V_own': False, 'V_thing': False, 'V_fact': True, 'V_nothing': True, 'V_say': False, 'V_right': True, 'V_john': False, 'V_although': True, 'V_played': False, 'V_find': False, 'V_script': False, 'V_come': False, 'V_ever': False, 'V_cast': False, 'V_since': False, 'V_did': False, 'V_star': False, 'V_plays': False, 'V_young': False, 'V_show': False, 'V_comes': False, 'V_m': False, 'V_part': False, 'V_original': True, 'V_actors': True, 'V_screen': True, 'V_without': False, 'V_again': False, 'V_acting': False, 'V_three': False, 'V_day': False, 'V_each': False, 'V_point': False, 'V_lot': False, 'V_least': False, 'V_takes': False, 'V_guy': False, 'V_quite': False, 'V_himself': False, 'V_away': False, 'V_during': False, 'V_family': False, 'V_effects': False, 'V_course': False, 'V_goes': False, 'V_minutes': ...

# %%
# training using naive Baysian classifier with a 95/5 split
train_set, test_set = featuresets[100:], featuresets[:100]
classifier = nltk.NaiveBayesClassifier.train(train_set)

# evaluate the accuracy of the classifier
print (nltk.classify.accuracy(classifier, test_set))
# the accuracy result may vary since we randomized the documents
# Out:
# 0.81

# %%
# show which features of classifier are most informative
print(classifier.show_most_informative_features(30))
# Out:
# Most Informative Features
#            V_outstanding = True              pos : neg    =     11.1 : 1.0
#                  V_mulan = True              pos : neg    =      8.9 : 1.0
#                 V_seagal = True              neg : pos    =      8.3 : 1.0
#            V_wonderfully = True              pos : neg    =      8.0 : 1.0
#                  V_damon = True              pos : neg    =      6.1 : 1.0
#                  V_flynt = True              pos : neg    =      5.6 : 1.0
#                 V_wasted = True              neg : pos    =      5.5 : 1.0
#                  V_awful = True              neg : pos    =      5.3 : 1.0
#                 V_poorly = True              neg : pos    =      5.2 : 1.0
#                   V_lame = True              neg : pos    =      5.2 : 1.0
#                  V_waste = True              neg : pos    =      4.9 : 1.0
#             V_ridiculous = True              neg : pos    =      4.8 : 1.0
#                    V_era = True              pos : neg    =      4.7 : 1.0
#                  V_worst = True              neg : pos    =      4.6 : 1.0
#              V_portrayal = True              pos : neg    =      4.5 : 1.0
#                  V_bland = True              neg : pos    =      4.4 : 1.0
#                   V_mess = True              neg : pos    =      4.2 : 1.0
#                 V_allows = True              pos : neg    =      4.2 : 1.0
#                   V_dull = True              neg : pos    =      4.1 : 1.0
#                   V_jedi = True              pos : neg    =      4.1 : 1.0
#              V_fantastic = True              pos : neg    =      4.1 : 1.0
#                 V_stupid = True              neg : pos    =      3.9 : 1.0
#                V_unfunny = True              neg : pos    =      3.9 : 1.0
#              V_memorable = True              pos : neg    =      3.7 : 1.0
#              V_laughable = True              neg : pos    =      3.7 : 1.0
#                 V_superb = True              pos : neg    =      3.7 : 1.0
#                 V_boring = True              neg : pos    =      3.7 : 1.0
#               V_terrific = True              pos : neg    =      3.6 : 1.0
#                  V_snake = True              neg : pos    =      3.6 : 1.0
#               V_terrible = True              neg : pos    =      3.5 : 1.0
# None
