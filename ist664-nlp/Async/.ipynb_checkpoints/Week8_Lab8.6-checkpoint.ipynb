# %% [markdown]
# Name: Sathish Kumar Rajendiran
# Chapter :  Sentiment Classifications in the NLTK
# Date: 11/22/2020
# Week: 8

# %%
#import libraries

# standard library
import os
import sys
from datetime import datetime
import time

# csv, xls, pandas & json
import pandas as pd
import json
import csv
import xlrd

# Language Processing
import nltk
from nltk import FreqDist
# import wordnet and shorten its name to wn
from nltk.corpus import wordnet as wn

# import sentence_polarity corpus 
from nltk.corpus import sentence_polarity
import random

# web requests
from urllib import request


##  Regular Expression to match non-alphabetic characters
import re

os.getcwd()
# Out:
# '/Users/sathishrajendiran/ist664-nlp/Async'

# %%
ls -ltr
# Out:
# total 1344
# -rw-r--r--@ 1 sathishrajendiran  staff  662534 Mar  7  2011 subjclueslen1-HLTEMNLP05.tff
# -rw-r--r--@ 1 sathishrajendiran  staff    1999 Nov 22 23:42 subjectivity.py
# -rw-r--r--  1 sathishrajendiran  staff   16534 Nov 23 00:09 Week8_Lab8.6.ipynb

# %% [markdown]
# # Movie Review Corpus Sentences with BOW (Corpus)

# %% [markdown]
# ## Sentiment/Opinion Classification (using the Movie Review corpus sentences)

# %% [markdown]
# In today’s lab, we will look at two ways to add features that are sometimes used in various sentiment or opinion classification problems.  In addition to providing a corpus of the 2000 positive and negative movie review documents, Pang and Lee had a subset of the sentences of the corpus annotated for sentiment in each sentence.  We will illustrate the process of sentiment classification on this corpus of sentences with positive or negative sentiment labels.
#
# We start by loading the sentence_polarity corpus and creating a list of documents where each document represents a single sentence with the words and its label.

# %%
sentences = sentence_polarity.sents()
print(len(sentences))
# Out:
# 10662

# %%
print(type(sentences))
# Out:
# <class 'nltk.corpus.reader.util.ConcatenatedCorpusView'>

# %%
print(sentence_polarity.categories())
# Out:
# ['neg', 'pos']

# %%
# sentences are already tokenized, show the first four sentences
for sent in sentences[:10]:
    print(sent)
# Out:
# ['simplistic', ',', 'silly', 'and', 'tedious', '.']
# ["it's", 'so', 'laddish', 'and', 'juvenile', ',', 'only', 'teenage', 'boys', 'could', 'possibly', 'find', 'it', 'funny', '.']
# ['exploitative', 'and', 'largely', 'devoid', 'of', 'the', 'depth', 'or', 'sophistication', 'that', 'would', 'make', 'watching', 'such', 'a', 'graphic', 'treatment', 'of', 'the', 'crimes', 'bearable', '.']
# ['[garbus]', 'discards', 'the', 'potential', 'for', 'pathological', 'study', ',', 'exhuming', 'instead', ',', 'the', 'skewed', 'melodrama', 'of', 'the', 'circumstantial', 'situation', '.']
# ['a', 'visually', 'flashy', 'but', 'narratively', 'opaque', 'and', 'emotionally', 'vapid', 'exercise', 'in', 'style', 'and', 'mystification', '.']
# ['the', 'story', 'is', 'also', 'as', 'unoriginal', 'as', 'they', 'come', ',', 'already', 'having', 'been', 'recycled', 'more', 'times', 'than', "i'd", 'care', 'to', 'count', '.']
# ['about', 'the', 'only', 'thing', 'to', 'give', 'the', 'movie', 'points', 'for', 'is', 'bravado', '--', 'to', 'take', 'an', 'entirely', 'stale', 'concept', 'and', 'push', 'it', 'through', 'the', "audience's", 'meat', 'grinder', 'one', 'more', 'time', '.']
# ['not', 'so', 'much', 'farcical', 'as', 'sour', '.']
# ['unfortunately', 'the', 'story', 'and', 'the', 'actors', 'are', 'served', 'with', 'a', 'hack', 'script', '.']
# ['all', 'the', 'more', 'disquieting', 'for', 'its', 'relatively', 'gore-free', 'allusions', 'to', 'the', 'serial', 'murders', ',', 'but', 'it', 'falls', 'down', 'in', 'its', 'attempts', 'to', 'humanize', 'its', 'subject', '.']

# %%
pos_sents = sentence_polarity.sents(categories='pos')
print(len(pos_sents))
# Out:
# 5331

# %%
neg_sents = sentence_polarity.sents(categories='neg')
print(len(neg_sents))
# Out:
# 5331

# %% [markdown]
# The movie review sentences are not labeled individually, but can be retrieved by category.  Look at the sentences by category to see how many positive and negative sentences there are.

# %%
documents = [(sent, cat) for cat in sentence_polarity.categories() 
    for sent in sentence_polarity.sents(categories=cat)]
print(documents[0])
print(documents[-1])
# Out:
# (['simplistic', ',', 'silly', 'and', 'tedious', '.'], 'neg')
# (['provides', 'a', 'porthole', 'into', 'that', 'noble', ',', 'trembling', 'incoherence', 'that', 'defines', 'us', 'all', '.'], 'pos')

# %% [markdown]
# Since the documents are in order by label, we mix them up for later separation into training and test sets.

# %%
random.shuffle(documents)

# %% [markdown]
# We need to define the set of words that will be used for features.  This is essentially all the words in the entire document collection, except that we will limit it to the 2000 most frequent words.  Note that we lowercase the words, but do not do stemming or remove stopwords.

# %%
all_words_list = [word for (sent,cat) in documents for word in sent]
all_words = nltk.FreqDist(all_words_list)
word_items = all_words.most_common(2000)
word_features = [word for (word, freq) in word_items]
# look at the first 50 words in the most frequent list of words
print(word_features[:50])
# Out:
# ['.', 'the', ',', 'a', 'and', 'of', 'to', 'is', 'in', 'that', 'it', 'as', 'but', 'with', 'film', 'this', 'for', 'its', 'an', 'movie', "it's", 'be', 'on', 'you', 'not', 'by', 'about', 'one', 'more', 'like', 'has', 'are', 'at', 'from', 'than', '"', 'all', '--', 'his', 'have', 'so', 'if', 'or', 'story', 'i', 'too', 'just', 'who', 'into', 'what']

# %% [markdown]
# Now we can define the features for each document, using just the words, sometimes called the BOW or unigram features.  The feature label will be ‘V_keyword’ for each keyword (aka word) in the word_features set, and the value of the feature will be Boolean, according to whether the word is contained in that document.

# %%
def document_features(document, word_features):
    document_words = set(document)
    features = {}
    for word in word_features:
        features['V_{}'.format(word)] = (word in document_words)
    return features

# %% [markdown]
# Define the feature sets for the documents.

# %%
featuresets = [(document_features(d,word_features), c) for (d,c) in documents]

# %%
print(len(featuresets)) # total number of words in the featuresets
print(featuresets[:10]) # top 5 features
# print(featuresets[5:]) # bottom 5 features)
# Out:
# 10662
# [({'V_.': True, 'V_the': True, 'V_,': True, 'V_a': True, 'V_and': True, 'V_of': True, 'V_to': True, 'V_is': True, 'V_in': True, 'V_that': False, 'V_it': False, 'V_as': True, 'V_but': False, 'V_with': False, 'V_film': False, 'V_this': False, 'V_for': False, 'V_its': False, 'V_an': False, 'V_movie': False, "V_it's": False, 'V_be': False, 'V_on': False, 'V_you': False, 'V_not': False, 'V_by': False, 'V_about': False, 'V_more': False, 'V_one': False, 'V_like': False, 'V_has': False, 'V_are': False, 'V_at': False, 'V_from': False, 'V_than': False, 'V_"': False, 'V_all': False, 'V_--': False, 'V_his': False, 'V_have': False, 'V_so': False, 'V_if': False, 'V_or': False, 'V_story': False, 'V_i': False, 'V_too': False, 'V_just': False, 'V_who': False, 'V_into': False, 'V_what': False, 'V_most': False, 'V_out': False, 'V_no': False, 'V_much': False, 'V_even': False, 'V_good': False, 'V_up': False, 'V_will': False, 'V_comedy': False, 'V_time': False, 'V_can': False, 'V_some': True, 'V_characters': False, 'V_only': False, 'V_little': False, 'V_way': False, 'V_their': False, 'V_funny': False, 'V_make': False, 'V_enough': False, 'V_been': False, 'V_very': False, 'V_your': False, 'V_never': False, 'V_when': False, 'V_makes': False, 'V_there': False, 'V_may': False, 'V_which': False, 'V_us': False, 'V_work': False, 'V_best': True, 'V_he': False, 'V_bad': False, 'V_director': False, "V_doesn't": False, 'V_)': False, 'V_any': False, 'V_?': False, 'V_(': False, 'V_love': False, 'V_would': False, 'V_life': False, 'V_they': False, 'V_while': False, 'V_:': True, 'V_we': False, 'V_was': False, 'V_movies': False, "V_there's": False, 'V_her': False, 'V_new': False, 'V_well': False, 'V_through': False, 'V_could': False, 'V_really': False, 'V_something': False, 'V_how': False, 'V_made': False, 'V_them': False, 'V_does': False, 'V_own': False, 'V_performances': False, "V_that's": False, 'V_should': False, 'V_many': False, 'V_drama': False, 'V_those': False, 'V_plot': False, 'V_films': False, 'V_look': False, 'V_still': False, "V_isn't": False, 'V_every': False, 'V_see': False, 'V_two': False, 'V_nothing': False, 'V_people': False, 'V_better': False, 'V_without': False, 'V_long': False, 'V_other': False, 'V_fun': False, 'V_get': False, 'V_off': False, 'V_action': False, 'V_being': False, 'V_both': False, 'V_great': False, 'V_though': False, 'V_might': False, 'V_big': False, "V_'": False, 'V_also': False, 'V_another': False, 'V_cast': False, 'V_do': False, 'V_humor': False, 'V_kind': True, 'V_first': False, 'V_between': False, 'V_audience': False, 'V_sense': False, 'V_over': False, 'V_such': False, 'V_character': False, 'V_ever': False, "V_don't": False, 'V_feels': False, 'V_performance': False, 'V_;': False, 'V_few': False, 'V_because': False, 'V_script': False, "V_film's": False, 'V_here': False, 'V_far': False, 'V_often': False, 'V_less': False, 'V_thing': False, 'V_seems': False, 'V_real': False, 'V_minutes': False, 'V_feel': False, 'V_thriller': False, 'V_world': False, 'V_picture': False, 'V_tale': False, 'V_almost': False, "V_can't": False, 'V_documentary': False, 'V_quite': False, 'V_down': False, 'V_yet': False, 'V_interesting': False, 'V_!': False, 'V_entertaining': True, 'V_these': False, 'V_screen': False, 'V_rather': False, 'V_my': False, "V_you're": False, 'V_end': False, 'V_itself': False, 'V_seen': False, 'V_watching': False, 'V_full': False, 'V_hollywood': False, 'V_take': False, 'V_ultimately': False, 'V_hard': False, 'V_go': False, 'V_heart': False, 'V_moments': False, 'V_romantic': False, 'V_de': False, 'V_comes': False, 'V_despite': False, 'V_lot': False, 'V_american': False, 'V_were': False, 'V_me': False, 'V_where': False, 'V_after': False, 'V_acting': False, 'V_before': False, 'V_family': False, 'V_original': False, 'V_then': False, 'V_old': False, 'V_had': False, 'V_find': False, 'V_right': False, 'V_human': False, 'V_worth': False, 'V_gets': False, 'V_same': False, 'V_takes': False, 'V_come': False, 'V_times': False, 'V_things': F ...

# %% [markdown]
# We create the training and test sets, train a Naïve Bayes classifier, and look at the accuracy, and this time we’ll do a 90/10 split of our approximately 10,000 documents.

# %%
train_set, test_set = featuresets[1000:], featuresets[:1000]
classifier = nltk.NaiveBayesClassifier.train(train_set)

print (nltk.classify.accuracy(classifier, test_set))
# Out:
# 0.74

# %% [markdown]
# The function show_most_informative_features shows the top ranked features according to the ratio of one label to the other one.  For example, if there are 20 times as many positive documents containing this word as negative ones, then the ratio will be reported as     20.00: 1.00   pos:neg.

# %%
classifier.show_most_informative_features(30)
# Out:
# Most Informative Features
#             V_engrossing = True              pos : neg    =     20.9 : 1.0
#                V_routine = True              neg : pos    =     16.4 : 1.0
#                V_generic = True              neg : pos    =     15.1 : 1.0
#             V_unexpected = True              pos : neg    =     14.9 : 1.0
#              V_inventive = True              pos : neg    =     14.2 : 1.0
#                   V_flat = True              neg : pos    =     13.1 : 1.0
#               V_supposed = True              neg : pos    =     13.1 : 1.0
#             V_refreshing = True              pos : neg    =     12.9 : 1.0
#           V_refreshingly = True              pos : neg    =     12.9 : 1.0
#                 V_boring = True              neg : pos    =     12.8 : 1.0
#                   V_warm = True              pos : neg    =     12.1 : 1.0
#              V_wonderful = True              pos : neg    =     12.1 : 1.0
#                   V_dull = True              neg : pos    =     11.6 : 1.0
#              V_realistic = True              pos : neg    =     11.6 : 1.0
#                   V_imax = True              pos : neg    =     11.6 : 1.0
#               V_captures = True              pos : neg    =     11.3 : 1.0
#               V_provides = True              pos : neg    =     10.9 : 1.0
#                  V_vivid = True              pos : neg    =     10.9 : 1.0
#                 V_unless = True              neg : pos    =     10.4 : 1.0
#               V_delicate = True              pos : neg    =     10.3 : 1.0
#                 V_stupid = True              neg : pos    =     10.3 : 1.0
#               V_annoying = True              neg : pos    =      9.7 : 1.0
#              V_offensive = True              neg : pos    =      9.7 : 1.0
#               V_chilling = True              pos : neg    =      9.6 : 1.0
#                   V_loud = True              neg : pos    =      9.5 : 1.0
#               V_powerful = True              pos : neg    =      9.4 : 1.0
#                  V_waste = True              neg : pos    =      9.1 : 1.0
#                V_harvard = True              neg : pos    =      9.1 : 1.0
#               V_mindless = True              neg : pos    =      9.1 : 1.0
#            V_examination = True              pos : neg    =      8.9 : 1.0

# %% [markdown]
# # Sentiment Lexicon:  Subjectivity Count features

# %%
# this function returns a dictionary where you can look up words and get back 
#     the four items of subjectivity information described above
def readSubjectivity(path):
    flexicon = open(path, 'r')
    # initialize an empty dictionary
    sldict = { }
    for line in flexicon:
        fields = line.split()   # default is to split on whitespace
        # split each field on the '=' and keep the second part as the value
        strength = fields[0].split("=")[1]
        word = fields[2].split("=")[1]
        posTag = fields[3].split("=")[1]
        stemmed = fields[4].split("=")[1]
        polarity = fields[5].split("=")[1]
        if (stemmed == 'y'):
            isStemmed = True
        else:
            isStemmed = False
        # put a dictionary entry with the word as the keyword
        #     and a list of the other values
        sldict[word] = [strength, posTag, isStemmed, polarity]
    return sldict

# %% [markdown]
# Now run the function that reads the file.  It creates a Subjectivity Lexicon that is represented here as a dictionary, where each word is mapped to a list containing the strength, POStag, whether it is stemmed and the polarity

# %%
SLpath = "/Users/sathishrajendiran/ist664-nlp/Async/subjclueslen1-HLTEMNLP05.tff"
SL = readSubjectivity(SLpath )

# %% [markdown]
# Now the variable SL (for Subjectivity Lexicon) is a dictionary where you can look up words and find the strength, POS tag, whether it is stemmed and polarity.  We can try out some words.

# %%
SL['absolute']
# Out:
# ['strongsubj', 'adj', False, 'neutral']

# %%
SL['shabby']
# Out:
# ['strongsubj', 'adj', False, 'negative']

# %%
strength, posTag, isStemmed, polarity = SL['absolute']

# %% [markdown]
# Now we create a feature extraction function that has all the word features as before, but also has two features ‘positivecount’ and ‘negativecount’.  These features contains counts of all the positive and negative subjectivity words, where each weakly subjective word is counted once and each strongly subjective word is counted twice.  Note that this is only one of the ways in which people count up the presence of positive, negative and neutral words in a document.

# %%
def SL_features(document, SL):
    document_words = set(document)
    features = {}
    for word in word_features:
        features['contains(%s)' % word] = (word in document_words)
        # count variables for the 4 classes of subjectivity
        weakPos = 0
        strongPos = 0
        weakNeg = 0
        strongNeg = 0
        for word in document_words:
            if word in SL:
                strength, posTag, isStemmed, polarity = SL[word]
                if strength == 'weaksubj' and polarity == 'positive':
                    weakPos += 1
                if strength == 'strongsubj' and polarity == 'positive':
                    strongPos += 1
                if strength == 'weaksubj' and polarity == 'negative':
                    weakNeg += 1
                if strength == 'strongsubj' and polarity == 'negative':
                    strongNeg += 1
                features['positivecount'] = weakPos + (2 * strongPos)
                features['negativecount'] = weakNeg + (2 * strongNeg)      
    return features

# %% [markdown]
# Now we create feature sets as before, but using this feature extraction function.

# %%
SL_featuresets = [(SL_features(d, SL), c) for (d,c) in documents]

# %%
SL_featuresets[0][0]['positivecount']
# Out:
# 9

# %%
SL_featuresets[0][0]['negativecount']
# Out:
# 3

# %%
SL_featuresets[0][1]
# Out:
# 'pos'

# %%
len(SL_featuresets)
# Out:
# 10662

# %% [markdown]
# We create the training and test sets, train a Naïve Bayes classifier, and look at the accuracy, and this time we’ll do a 90/10 split of our approximately 10,000 documents.

# %%
train_set, test_set = SL_featuresets[1000:], SL_featuresets[:1000]
classifier = nltk.NaiveBayesClassifier.train(train_set)
print(nltk.classify.accuracy(classifier, test_set))
# Out:
# 0.753

# %% [markdown]
# In my random training, test split, these particular sentiment features did improve the classification on this dataset.  But also note that there are several different ways to represent features for a sentiment lexicon, e.g. instead of counting the sentiment words, we could get one overall score by subtracting the number of negative words from positive words, or other ways to score the sentiment words.  Also note that there are many different sentiment lexicons to try.

# %% [markdown]
# # Adding Negation Features

# %% [markdown]
# Negation of opinions is an important part of opinion classification.  Here we try a simple strategy.  We look for negation words "not", "never" and "no" and negation that appears in contractions of the form "doesn’t".
#
# One strategy with negation words is to negate the word following the negation word, while other strategies negate all words up to the next punctuation or use syntax to find the scope of the negation.
#
#
# Here is one list of negation words, including some adverbs called “approximate negators”:
# no, not, never, none, rather, hardly, scarcely, rarely, seldom, neither, nor,
# couldn't, wasn't, didn't, wouldn't, shouldn't, weren't, don't, doesn't, haven't, hasn't, won't, hadn't
#
# The form of some of the words is a verb followed by n’t.  Now in the Movie Review Corpus itself, the tokenization has these words all split into 3 words, e.g. “couldn”, “’”, and “t”.  (and I have a NOT_features definition for this case).  But in this sentence_polarity corpus, the tokenization keeps these forms of negation as one word ending in “n’t”.

# %%
for sent in list(sentences)[:50]:
     for word in sent:
        if (word.endswith("n't")):
            print(sent)
# Out:
# ['there', 'is', 'a', 'difference', 'between', 'movies', 'with', 'the', 'courage', 'to', 'go', 'over', 'the', 'top', 'and', 'movies', 'that', "don't", 'care', 'about', 'being', 'stupid']
# ['a', 'farce', 'of', 'a', 'parody', 'of', 'a', 'comedy', 'of', 'a', 'premise', ',', 'it', "isn't", 'a', 'comparison', 'to', 'reality', 'so', 'much', 'as', 'it', 'is', 'a', 'commentary', 'about', 'our', 'knowledge', 'of', 'films', '.']
# ['i', "didn't", 'laugh', '.', 'i', "didn't", 'smile', '.', 'i', 'survived', '.']
# ['i', "didn't", 'laugh', '.', 'i', "didn't", 'smile', '.', 'i', 'survived', '.']
# ['most', 'of', 'the', 'problems', 'with', 'the', 'film', "don't", 'derive', 'from', 'the', 'screenplay', ',', 'but', 'rather', 'the', 'mediocre', 'performances', 'by', 'most', 'of', 'the', 'actors', 'involved']
# ['the', 'lack', 'of', 'naturalness', 'makes', 'everything', 'seem', 'self-consciously', 'poetic', 'and', 'forced', '.', '.', '.', "it's", 'a', 'pity', 'that', "[nelson's]", 'achievement', "doesn't", 'match', 'his', 'ambition', '.']

# %%
negationwords = ['no', 'not', 'never', 'none', 'nowhere', 'nothing', 'noone'
                 , 'rather', 'hardly', 'scarcely', 'rarely', 'seldom', 'neither', 'nor']

# %% [markdown]
# Start the feature set with all 2000 word features and 2000 Not word features set to false.  If a negation occurs, add the following word as a Not word feature (if it’s in the top 2000 feature words), and otherwise add it as a regular feature word.

# %%
def NOT_features(document, word_features, negationwords):
    features = {}
    for word in word_features:
#         features['contains({})'.format(word)] = False
#         features['contains(NOT{})'.format(word)] = False
        features['V_{}'.format(word)] = False
        features['V_NOT{}'.format(word)] = False
    # go through document words in order
    for i in range(0, len(document)):
        word = document[i]
        if ((i + 1) < len(document)) and ((word in negationwords) or (word.endswith("n't"))):
            i += 1
#             features['contains(NOT{})'.format(document[i])] = (document[i] in word_features)
#         else:
#             features['contains({})'.format(word)] = (word in word_features)
            features['V_{}'.format(document[i])] = (document[i] in word_features)
        else:
            features['V_NOT{}'.format(word)] = (word in word_features)
    return features

# %% [markdown]
# Create feature sets as before, using the NOT_features extraction funtion, train the classifier and test the accuracy.

# %%
NOT_featuresets = [(NOT_features(d, word_features, negationwords), c) for (d, c) in documents]
NOT_featuresets[0][0]['contains(NOTlike)']
NOT_featuresets[0][0]['contains(always)']
# Out:
# False

# %%
train_set, test_set = NOT_featuresets[200:], NOT_featuresets[:200]
classifier = nltk.NaiveBayesClassifier.train(train_set)
print (nltk.classify.accuracy(classifier, test_set))
# Out:
# 0.75

# %%
classifier.show_most_informative_features(30)
# Out:
# Most Informative Features
#     contains(engrossing) = True              pos : neg    =     21.7 : 1.0
#       contains(mediocre) = True              neg : pos    =     17.0 : 1.0
#        contains(generic) = True              neg : pos    =     16.3 : 1.0
#        contains(routine) = True              neg : pos    =     16.3 : 1.0
#      contains(inventive) = True              pos : neg    =     15.7 : 1.0
#     contains(refreshing) = True              pos : neg    =     14.3 : 1.0
#           contains(flat) = True              neg : pos    =     14.2 : 1.0
#         contains(boring) = True              neg : pos    =     14.2 : 1.0
#             contains(90) = True              neg : pos    =     13.7 : 1.0
#   contains(refreshingly) = True              pos : neg    =     13.0 : 1.0
#           contains(warm) = True              pos : neg    =     13.0 : 1.0
#           contains(dull) = True              neg : pos    =     12.6 : 1.0
#      contains(wonderful) = True              pos : neg    =     12.6 : 1.0
#      contains(NOTenough) = True              neg : pos    =     12.3 : 1.0
#          contains(stale) = True              neg : pos    =     11.7 : 1.0
#      contains(realistic) = True              pos : neg    =     11.7 : 1.0
#         contains(stupid) = True              neg : pos    =     11.4 : 1.0
#       contains(captures) = True              pos : neg    =     11.4 : 1.0
#       contains(provides) = True              pos : neg    =     11.4 : 1.0
#         contains(unless) = True              neg : pos    =     10.3 : 1.0
#       contains(tiresome) = True              neg : pos    =     10.3 : 1.0
#       contains(mindless) = True              neg : pos    =     10.3 : 1.0
#      contains(offensive) = True              neg : pos    =     10.3 : 1.0
#       contains(chilling) = True              pos : neg    =     10.3 : 1.0
#       contains(powerful) = True              pos : neg    =     10.1 : 1.0
#           contains(loud) = True              neg : pos    =      9.8 : 1.0
#     contains(meandering) = True              neg : pos    =      9.7 : 1.0
#       contains(annoying) = True              neg : pos    =      9.7 : 1.0
#    contains(mesmerizing) = True              pos : neg    =      9.7 : 1.0
#         contains(tender) = True              pos : neg    =      9.7 : 1.0

# %%
NOT_featuresets = [(NOT_features(d, word_features, negationwords), c) for (d, c) in documents]
print(NOT_featuresets[0][0]['V_NOTcare'])
print(NOT_featuresets[0][0]['V_always'])
# Out:
# False
# False

# %%
len(NOT_featuresets)
# Out:
# 10662

# %% [markdown]
# We create the training and test sets, train a Naïve Bayes classifier, and look at the accuracy, and this time we’ll do a 90/10 split of our approximately 10,000 documents.

# %%
train_set, test_set = NOT_featuresets[1000:], NOT_featuresets[:1000]
classifier = nltk.NaiveBayesClassifier.train(train_set)
print (nltk.classify.accuracy(classifier, test_set))
# Out:
# 0.773

# %%
classifier.show_most_informative_features(30)
# Out:
# Most Informative Features
#          V_NOTengrossing = True              pos : neg    =     21.7 : 1.0
#            V_NOTmediocre = True              neg : pos    =     17.0 : 1.0
#             V_NOTgeneric = True              neg : pos    =     16.3 : 1.0
#             V_NOTroutine = True              neg : pos    =     16.3 : 1.0
#           V_NOTinventive = True              pos : neg    =     15.7 : 1.0
#          V_NOTrefreshing = True              pos : neg    =     14.3 : 1.0
#                V_NOTflat = True              neg : pos    =     14.2 : 1.0
#              V_NOTboring = True              neg : pos    =     14.2 : 1.0
#                  V_NOT90 = True              neg : pos    =     13.7 : 1.0
#                V_NOTwarm = True              pos : neg    =     13.0 : 1.0
#        V_NOTrefreshingly = True              pos : neg    =     13.0 : 1.0
#                V_NOTdull = True              neg : pos    =     12.6 : 1.0
#           V_NOTwonderful = True              pos : neg    =     12.6 : 1.0
#                 V_enough = True              neg : pos    =     12.3 : 1.0
#               V_NOTstale = True              neg : pos    =     11.7 : 1.0
#           V_NOTrealistic = True              pos : neg    =     11.7 : 1.0
#              V_NOTstupid = True              neg : pos    =     11.4 : 1.0
#            V_NOTcaptures = True              pos : neg    =     11.4 : 1.0
#            V_NOTprovides = True              pos : neg    =     11.4 : 1.0
#            V_NOTtiresome = True              neg : pos    =     10.3 : 1.0
#            V_NOTmindless = True              neg : pos    =     10.3 : 1.0
#              V_NOTunless = True              neg : pos    =     10.3 : 1.0
#           V_NOToffensive = True              neg : pos    =     10.3 : 1.0
#            V_NOTchilling = True              pos : neg    =     10.3 : 1.0
#            V_NOTpowerful = True              pos : neg    =     10.1 : 1.0
#                V_NOTloud = True              neg : pos    =      9.8 : 1.0
#            V_NOTannoying = True              neg : pos    =      9.7 : 1.0
#          V_NOTmeandering = True              neg : pos    =      9.7 : 1.0
#         V_NOTmesmerizing = True              pos : neg    =      9.7 : 1.0
#              V_NOTtender = True              pos : neg    =      9.7 : 1.0

# %% [markdown]
# In my random split, using the negation features did improve the classification.

# %% [markdown]
# Other features
#
# There are other types of possible features.  For example, sometimes people use bigrams in addition to just words/unigrams or use the counts of POS tags, which we will look at next week.  Also, there are many other forms of negation features.
#
# For some problems, the word features can be pruned with a stop word list, but care should be taken that the list doesn’t remove any negation or useful function words.  A very small stop word list is probably better than a large one.

# %% [markdown]
# # using a stopword list to prune the word features

# %% [markdown]
# We’ll start with the NLTK stop word list, but we’ll remove some of the negation words, or parts of words, that our negation filter uses. This list is still pretty large.

# %%
stopwords = nltk.corpus.stopwords.words('english')
len(stopwords)
# Out:
# 179

# %%
stopwords # review the stopwords
# Out:
# ['i',
#  'me',
#  'my',
#  'myself',
#  'we',
#  'our',
#  'ours',
#  'ourselves',
#  'you',
#  "you're",
#  "you've",
#  "you'll",
#  "you'd",
#  'your',
#  'yours',
#  'yourself',
#  'yourselves',
#  'he',
#  'him',
#  'his',
#  'himself',
#  'she',
#  "she's",
#  'her',
#  'hers',
#  'herself',
#  'it',
#  "it's",
#  'its',
#  'itself',
#  'they',
#  'them',
#  'their',
#  'theirs',
#  'themselves',
#  'what',
#  'which',
#  'who',
#  'whom',
#  'this',
#  'that',
#  "that'll",
#  'these',
#  'those',
#  'am',
#  'is',
#  'are',
#  'was',
#  'were',
#  'be',
#  'been',
#  'being',
#  'have',
#  'has',
#  'had',
#  'having',
#  'do',
#  'does',
#  'did',
#  'doing',
#  'a',
#  'an',
#  'the',
#  'and',
#  'but',
#  'if',
#  'or',
#  'because',
#  'as',
#  'until',
#  'while',
#  'of',
#  'at',
#  'by',
#  'for',
#  'with',
#  'about',
#  'against',
#  'between',
#  'into',
#  'through',
#  'during',
#  'before',
#  'after',
#  'above',
#  'below',
#  'to',
#  'from',
#  'up',
#  'down',
#  'in',
#  'out',
#  'on',
#  'off',
#  'over',
#  'under',
#  'again',
#  'further',
#  'then',
#  'once',
#  'here',
#  'there',
#  'when',
#  'where',
#  'why',
#  'how',
#  'all',
#  'any',
#  'both',
#  'each',
#  'few',
#  'more',
#  'most',
#  'other',
#  'some',
#  'such',
#  'no',
#  'nor',
#  'not',
#  'only',
#  'own',
#  'same',
#  'so',
#  'than',
#  'too',
#  'very',
#  's',
#  't',
#  'can',
#  'will',
#  'just',
#  'don',
#  "don't",
#  'should',
#  "should've",
#  'now',
#  'd',
#  'll',
#  'm',
#  'o',
#  're',
#  've',
#  'y',
#  'ain',
#  'aren',
#  "aren't",
#  'couldn',
#  "couldn't",
#  'didn',
#  "didn't",
#  'doesn',
#  "doesn't",
#  'hadn',
#  "hadn't",
#  'hasn',
#  "hasn't",
#  'haven',
#  "haven't",
#  'isn',
#  "isn't",
#  'ma',
#  'mightn',
#  "mightn't",
#  'mustn',
#  "mustn't",
#  'needn',
#  "needn't",
#  'shan',
#  "shan't",
#  'shouldn',
#  "shouldn't",
#  'wasn',
#  "wasn't",
#  'weren',
#  "weren't",
#  'won',
#  "won't",
#  'wouldn',
#  "wouldn't"]

# %%
newstopwords = [word for word in stopwords if word not in negationwords]
len(newstopwords)
# Out:
# 176

# %%
newstopwords
# Out:
# ['i',
#  'me',
#  'my',
#  'myself',
#  'we',
#  'our',
#  'ours',
#  'ourselves',
#  'you',
#  "you're",
#  "you've",
#  "you'll",
#  "you'd",
#  'your',
#  'yours',
#  'yourself',
#  'yourselves',
#  'he',
#  'him',
#  'his',
#  'himself',
#  'she',
#  "she's",
#  'her',
#  'hers',
#  'herself',
#  'it',
#  "it's",
#  'its',
#  'itself',
#  'they',
#  'them',
#  'their',
#  'theirs',
#  'themselves',
#  'what',
#  'which',
#  'who',
#  'whom',
#  'this',
#  'that',
#  "that'll",
#  'these',
#  'those',
#  'am',
#  'is',
#  'are',
#  'was',
#  'were',
#  'be',
#  'been',
#  'being',
#  'have',
#  'has',
#  'had',
#  'having',
#  'do',
#  'does',
#  'did',
#  'doing',
#  'a',
#  'an',
#  'the',
#  'and',
#  'but',
#  'if',
#  'or',
#  'because',
#  'as',
#  'until',
#  'while',
#  'of',
#  'at',
#  'by',
#  'for',
#  'with',
#  'about',
#  'against',
#  'between',
#  'into',
#  'through',
#  'during',
#  'before',
#  'after',
#  'above',
#  'below',
#  'to',
#  'from',
#  'up',
#  'down',
#  'in',
#  'out',
#  'on',
#  'off',
#  'over',
#  'under',
#  'again',
#  'further',
#  'then',
#  'once',
#  'here',
#  'there',
#  'when',
#  'where',
#  'why',
#  'how',
#  'all',
#  'any',
#  'both',
#  'each',
#  'few',
#  'more',
#  'most',
#  'other',
#  'some',
#  'such',
#  'only',
#  'own',
#  'same',
#  'so',
#  'than',
#  'too',
#  'very',
#  's',
#  't',
#  'can',
#  'will',
#  'just',
#  'don',
#  "don't",
#  'should',
#  "should've",
#  'now',
#  'd',
#  'll',
#  'm',
#  'o',
#  're',
#  've',
#  'y',
#  'ain',
#  'aren',
#  "aren't",
#  'couldn',
#  "couldn't",
#  'didn',
#  "didn't",
#  'doesn',
#  "doesn't",
#  'hadn',
#  "hadn't",
#  'hasn',
#  "hasn't",
#  'haven',
#  "haven't",
#  'isn',
#  "isn't",
#  'ma',
#  'mightn',
#  "mightn't",
#  'mustn',
#  "mustn't",
#  'needn',
#  "needn't",
#  'shan',
#  "shan't",
#  'shouldn',
#  "shouldn't",
#  'wasn',
#  "wasn't",
#  'weren',
#  "weren't",
#  'won',
#  "won't",
#  'wouldn',
#  "wouldn't"]

# %% [markdown]
# Now take the new stop words out of the collection of all words, and then take the top 2000 to be the word features.

# %%
new_all_words_list = [word for word in all_words_list if word not in newstopwords]

# %% [markdown]
# Now continue to get new word features of length 2000 after the stopwords are removed:

# %%
new_all_words = nltk.FreqDist(new_all_words_list)

# %%
new_word_items = new_all_words.most_common(2000)

# %% [markdown]
# #### Build new word feature

# %%
new_word_features = [word for (word,count) in new_word_items]

# %%
print(new_word_features[:30])
# Out:
# ['.', ',', 'film', 'movie', 'not', 'one', 'like', '"', '--', 'story', 'no', 'much', 'even', 'good', 'comedy', 'time', 'characters', 'little', 'way', 'funny', 'make', 'enough', 'never', 'makes', 'may', 'us', 'work', 'best', 'bad', 'director']

# %% [markdown]
# # Adding to BOW / Document features

# %%
def document_features_NEW(document, new_word_features):
    document_words = set(document)
    features = {}
    for word in new_word_features:
        features['V_{}'.format(word)] = (word in document_words)
    return features

# %%
featuresets_NEW = [(document_features_NEW(d,new_word_features), c) for (d,c) in documents]
print(len(featuresets_NEW)) # total number of words in the featuresets
# Out:
# 10662

# %%
featuresets_NEW[:10]
# Out:
# [({'V_.': True,
#    'V_,': True,
#    'V_film': False,
#    'V_movie': False,
#    'V_not': False,
#    'V_one': False,
#    'V_like': True,
#    'V_"': False,
#    'V_--': False,
#    'V_story': False,
#    'V_no': False,
#    'V_much': False,
#    'V_even': False,
#    'V_good': False,
#    'V_comedy': False,
#    'V_time': False,
#    'V_characters': False,
#    'V_little': False,
#    'V_way': False,
#    'V_funny': False,
#    'V_make': False,
#    'V_enough': False,
#    'V_never': False,
#    'V_makes': False,
#    'V_may': False,
#    'V_us': False,
#    'V_work': False,
#    'V_best': False,
#    'V_bad': False,
#    'V_director': False,
#    'V_)': False,
#    'V_?': False,
#    'V_(': False,
#    'V_love': True,
#    'V_would': False,
#    'V_life': False,
#    'V_:': False,
#    'V_movies': False,
#    "V_there's": False,
#    'V_new': False,
#    'V_well': False,
#    'V_could': False,
#    'V_something': False,
#    'V_really': False,
#    'V_made': False,
#    'V_performances': False,
#    "V_that's": False,
#    'V_drama': False,
#    'V_many': False,
#    'V_films': False,
#    'V_look': False,
#    'V_plot': False,
#    'V_still': False,
#    'V_every': False,
#    'V_see': False,
#    'V_two': False,
#    'V_nothing': False,
#    'V_people': False,
#    'V_better': True,
#    'V_without': False,
#    'V_long': False,
#    'V_get': False,
#    'V_fun': False,
#    'V_action': False,
#    'V_great': False,
#    'V_though': False,
#    'V_might': False,
#    'V_big': False,
#    "V_'": False,
#    'V_also': False,
#    'V_another': False,
#    'V_cast': False,
#    'V_humor': False,
#    'V_first': False,
#    'V_kind': False,
#    'V_audience': False,
#    'V_sense': False,
#    'V_ever': False,
#    'V_character': False,
#    'V_feels': True,
#    'V_;': False,
#    'V_performance': False,
#    'V_script': False,
#    "V_film's": False,
#    'V_far': False,
#    'V_often': False,
#    'V_thing': False,
#    'V_less': False,
#    'V_seems': False,
#    'V_minutes': False,
#    'V_real': False,
#    'V_feel': False,
#    'V_picture': False,
#    'V_almost': False,
#    'V_world': False,
#    'V_thriller': False,
#    'V_tale': False,
#    "V_can't": False,
#    'V_documentary': False,
#    'V_quite': False,
#    'V_interesting': False,
#    'V_yet': False,
#    'V_!': False,
#    'V_entertaining': False,
#    'V_rather': False,
#    'V_screen': False,
#    'V_end': False,
#    'V_watching': False,
#    'V_hollywood': False,
#    'V_take': False,
#    'V_seen': False,
#    'V_full': False,
#    'V_ultimately': False,
#    'V_hard': False,
#    'V_go': False,
#    'V_heart': False,
#    'V_romantic': False,
#    'V_de': False,
#    'V_comes': False,
#    'V_moments': False,
#    'V_lot': False,
#    'V_despite': False,
#    'V_american': False,
#    'V_acting': False,
#    'V_family': False,
#    'V_old': False,
#    'V_original': False,
#    'V_find': False,
#    'V_right': False,
#    'V_gets': False,
#    'V_worth': False,
#    'V_human': False,
#    'V_takes': False,
#    'V_come': False,
#    'V_things': False,
#    'V_times': False,
#    'V_dialogue': False,
#    'V_scenes': False,
#    'V_back': False,
#    'V_actors': False,
#    'V_man': False,
#    'V_watch': False,
#    'V_material': False,
#    'V_compelling': False,
#    'V_young': False,
#    'V_music': False,
#    'V_years': False,
#    'V_works': False,
#    'V_emotional': False,
#    'V_think': False,
#    'V_seem': False,
#    'V_anyone': False,
#    'V_want': False,
#    'V_gives': False,
#    'V_least': False,
#    'V_going': False,
#    'V_know': False,
#    'V_say': False,
#    'V_part': False,
#    'V_sometimes': False,
#    'V_piece': False,
#    'V_cinematic': False,
#    'V_entertainment': False,
#    'V_point': False,
#    'V_give': False,
#    'V_subject': False,
#    'V_kids': False,
#    'V_pretty': False,
#    'V_last': False,
#    'V_special': True,
#    'V_bit': False,
#    'V_keep': False,
#    'V_making': False,
#    'V_cinema': False,
#    'V_dull': False,
#    'V_together': False,
#    'V_whole': False,
#    'V_fascinating': False,
#    'V_anything': False,
#    'V_fans': False,
#    'V_year': False,
#    'V_-': False,
#    'V_away': False,
#    'V_moving': False,
#    'V_since': False,
#    'V_style': False,
#    'V_manages': False,
#    'V_need': False,
#    'V_laughs': False,
#    'V_star': False,
#    'V_true': False,
#    'V_show': False,
#    'V_sweet': False,
#    'V_clever': False,
#    'V_experience': False,
#    'V_offers': False,
#    'V_history': False,
#    'V_always': False,
#    'V_direction': False,
#    'V_mr': False,
#    'V_simply': False,
#    'V_high': False,
#    'V_silly': False,
#    'V_instead': False,
#    'V_dark': False,
#    'V_charm': False,
#    'V_whose': False,
#    'V_predictable': False,
#    'V_care': False,
#    'V_actually': False,
#    'V_flick': False,
#    'V_nearly': False,
#    'V_art': False,
#    'V_everything': False,
#    'V_visual': False,
#    'V_series': False,
#    'V_around': False,
#    'V_title': False,
#    'V_matter': False,
#    'V_video': False,
#    'V_place': False,
#    'V_comic': False,
#    'V_narrative': False,
#    "V_he's": False,
#    'V_idea': False,
#    'V_done': False,
#    'V_screenplay': False,
#    'V_goes': False,
#    'V_short': False,
#    'V_war': False,
#    'V_trying': False,
#    'V_women': False,
#    'V_genre': False,
#    'V_probably': False,
#    "V_movie's": False,
#    'V_familiar': False,
#    'V_premise': False,
#    'V_plays': False,
#    'V_horror': False,
#    'V_enjoyable': False,
#    'V_turns': False,
#    'V_three': False,
#    'V_home': False,
#    'V_filmmakers': False,
#    'V_set': False,
#    'V_although': False,
#    'V_becomes': False,
#    'V_engaging': False,
#    'V_lacks': False,
#    'V_worst': False,
#    'V_smart': False,
#    'V_feature': False,
#    'V_feeling': False,
#    'V_enjoy': False,
#    'V_power': False,
#    'V_effects': False,
#    'V_especially': False,
#    'V_ending': False,
#    'V_half': False,
#    'V_study': False,
#    'V_amusing': False,
#    'V_charming': False,
#    'V_effort': False,
#    'V_day': False,
#    'V_intelligent': False,
#    'V_strong': False,
#    'V_boring': False,
#    'V_debut': False,
#    'V_theater': False,
#    'V_lack': False,
#    'V_likely': False,
#    'V_portrait': False,
#    'V_john': False,
#    'V_men': False,
#    'V_romance': False,
#    'V_put': False,
#    'V_version': False,
#    "V_what's": False,
#    'V_certainly': False,
#    'V_sort': False,
#    'V_mostly': False,
#    'V_else': False,
#    'V_beautiful': False,
#    'V_next': False,
#    'V_message': False,
#    'V_problem': False,
#    'V_level': False,
#    'V_looking': False,
#    'V_surprisingly': False,
#    'V_become': False,
#    'V_easy': False,
#    'V_beautifully': False,
#    'V_quirky': False,
#    'V_lives': False,
#    'V_wit': False,
#    'V_hours': False,
#    'V_rare': False,
#    'V_exercise': False,
#    'V_solid': False,
#    'V_along': False,
#    'V_mind': False,
#    'V_play': False,
#    'V_fine': False,
#    'V_looks': True,
#    'V_directed': False,
#    'V_whether': False,
#    'V_fresh': False,
#    'V_sure': False,
#    'V_obvious': False,
#    'V_face': False,
#    'V_ideas': False,
#    'V_mess': False,
#    'V_leave': False,
#    'V_completely': False,
#    'V_modern': False,
#    'V_french': False,
#    'V_either': False,
#    'V_powerful': False,
#    'V_past': False,
#    'V_interest': False,
#    'V_energy': False,
#    'V_neither': False,
#    'V_melodrama': False,
#    'V_viewers': False,
#    'V_dramatic': False,
#    'V_beyond': False,
#    'V_shot': False,
#    'V_classic': False,
#    'V_fact': False,
#    'V_reason': False,
#    'V_recent': False,
#    'V_children': False,
#    'V_filmmaking': False,
#    'V_delivers': False,
#    'V_shows': False,
#    'V_tone': False,
#    'V_suspense': False,
#    'V_fails': False,
#    'V_stuff': False,
#    'V_culture': False,
#    "V_i'm": False,
#    'V_truly': False,
#    'V_deeply': False,
#    'V_believe': False,
#    'V_everyone': False,
#    'V_left': False,
#    'V_intriguing': False,
#    'V_slow': False,
#    'V_ends': False,
#    'V_death': False,
#    'V_actor': False,
#    'V_jokes': False,
#    'V_serious': False,
#    'V_book': False,
#    'V_tries': False,
#    'V_black': False,
#    'V_ride': False,
#    'V_occasionally': False,
#    'V_small': False,
#    'V_spirit': False,
#    'V_sad': False,
#    'V_production': False,
#    'V_audiences': False,
#    'V_tv': False,
#    'V_touching': False,
#    'V_light': False,
#    'V_formula': False,
#    'V_camera': False,
#    'V_hilarious': False,
#    'V_role': False,
#    'V_exactly': False,
#    'V_terrific': False,
#    'V_proves': False,
#    'V_remains': False,
#    'V_satisfying': False,
#    'V_opera': False,
#    'V_passion': False,
#    'V_storytelling': False,
#    'V_dumb': False,
#    'V_reality': False,
#    'V_adventure': False,
#    'V_must': False,
#    'V_project': False,
#    'V_filmmaker': False,
#    'V_nor': False,
#    'V_seeing': False,
#    'V_images': False,
#    'V_already': False,
#    'V_got': False,
#    'V_different': False,
#    'V_line': False,
#    'V_talent': False,
#    'V_stories': False,
#    'V_impossible': False,
#    'V_scene': False,
#    'V_perfect': False,
#    'V_journey': False,
#    'V_girl': False,
#    'V_gags': False,
#    'V_attempt': False,
#    'V_personal': False,
#    'V_simple': False,
#    'V_particularly': False,
#    'V_easily': False,
#    'V_turn': False,
#    'V_close': False,
#    'V_summer': False,
#    'V_pleasure': False,
#    'V_given': False,
#    'V_psychological': False,
#    'V_animation': False,
#    'V_complex': False,
#    'V_sex': False,
#    'V_pretentious': False,
#    'V_honest': False,
#    'V_hour': False,
#    'V_flat': False,
#    'V_case': False,
#    'V_ways': False,
#    'V_found': False,
#    'V_falls': False,
#    'V_michael': False,
#    'V_intelligence': False,
#    'V_earnest': False,
#    'V_difficult': False,
#    'V_head': False,
#    'V_cliches': False,
#    'V_political': False,
#    'V_mystery': False,
#    'V_visually': False,
#    'V_sequel': False,
#    'V_getting': False,
#    'V_leaves': False,
#    'V_social': False,
#    'V_coming-of-age': False,
#    'V_thought': False,
#    'V_game': False,
#    'V_uses': False,
#    'V_violence': False,
#    'V_none': False,
#    'V_que': False,
#    'V_memorable': False,
#    'V_written': False,
#    'V_crime': False,
#    'V_writing': False,
#    'V_tell': False,
#    'V_gone': False,
#    'V_wrong': False,
#    'V_keeps': False,
#    'V_rich': False,
#    'V_help': False,
#    'V_brilliant': False,
#    'V_side': False,
#    'V_laugh': False,
#    'V_job': False,
#    'V_told': False,
#    'V_overall': False,
#    'V_satire': False,
#    'V_live': False,
#    'V_finally': False,
#    'V_contrived': False,
#    'V_needs': False,
#    'V_spy': False,
#    'V_days': False,
#    'V_novel': False,
#    'V_barely': False,
#    'V_lost': False,
#    'V_rarely': False,
#    'V_otherwise': False,
#    'V_second': False,
#    'V_elements': False,
#    'V_cold': False,
#    'V_boy': False,
#    'V_cool': False,
#    'V_final': False,
#    'V_starts': False,
#    'V_possible': False,
#    'V_nature': False,
#    'V_entirely': False,
#    'V_guys': False,
#    'V_taste': False,
#    'V_several': False,
#    'V_imagine': False,
#    'V_appeal': False,
#    'V_acted': False,
#    'V_approach': False,
#    'V_thoughtful': False,
#    'V_wonderful': False,
#    'V_fairly': False,
#    'V_excellent': False,
#    'V_warm': False,
#    'V_running': False,
#    'V_eyes': False,
#    'V_tragedy': False,
#    'V_insight': False,
#    'V_concept': False,
#    'V_creepy': False,
#    'V_moral': False,
#    'V_surprising': False,
#    'V_act': False,
#    'V_lead': False,
#    'V_wild': False,
#    'V_truth': False,
#    'V_mood': False,
#    'V_soap': False,
#    'V_perhaps': False,
#    'V_behind': False,
#    'V_comedies': False,
#    'V_among': False,
#    'V_form': False,
#    'V_quality': False,
#    'V_others': False,
#    'V_viewer': False,
#    'V_engrossing': False,
#    'V_expect': False,
#    "V_they're": False,
#    'V_tedious': False,
#    'V_thoroughly': False,
#    'V_attention': False,
#    'V_result': False,
#    'V_call': False,
#    'V_david': False,
#    'V_bring': False,
#    'V_remarkable': False,
#    'V_hero': False,
#    'V_imagination': False,
#    'V_emotionally': False,
#    'V_entire': False,
#    'V_adults': False,
#    'V_sci-fi': False,
#    'V_gorgeous': False,
#    'V_\x96': False,
#    'V_strange': False,
#    'V_add': False,
#    'V_moment': False,
#    'V_remake': False,
#    'V_adaptation': False,
#    'V_usual': False,
#    "V_i've": False,
#    'V_teen': False,
#    'V_change': False,
#    'V_start': False,
#    'V_genuine': False,
#    'V_future': False,
#    'V_nice': False,
#    'V_tired': False,
#    'V_knows': False,
#    'V_perfectly': False,
#    'V_latest': False,
#    'V_animated': False,
#    'V_sharp': False,
#    'V_disney': False,
#    'V_rock': False,
#    'V_vision': False,
#    'V_quiet': False,
#    'V_witty': False,
#    'V_bland': False,
#    'V_four': False,
#    'V_epic': False,
#    'V_la': False,
#    'V_points': False,
#    'V_parents': False,
#    'V_depth': False,
#    'V_period': False,
#    'V_impressive': False,
#    'V_maybe': False,
#    'V_gentle': False,
#    'V_plenty': False,
#    'V_beauty': False,
#    'V_worse': False,
#    'V_events': False,
#    'V_taking': False,
#    'V_begins': False,
#    'V_effective': False,
#    'V_merely': False,
#    'V_thanks': False,
#    'V_hope': False,
#    'V_wonder': False,
#    'V_somewhat': False,
#    'V_appealing': False,
#    'V_deep': False,
#    'V_dead': False,
#    'V_worthy': False,
#    'V_offer': False,
#    'V_clear': False,
#    'V_surprise': False,
#    'V_awful': False,
#    'V_sit': False,
#    'V_writer-director': False,
#    'V_emotions': False,
#    'V_important': False,
#    'V_lots': False,
#    'V_decent': False,
#    'V_ambitious': False,
#    'V_straight': False,
#    'V_hit': False,
#    'V_however': False,
#    'V_guy': False,
#    "V_year's": False,
#    'V_provides': False,
#    'V_woman': False,
#    'V_definitely': False,
#    'V_unfortunately': False,
#    'V_someone': False,
#    'V_career': False,
#    'V_fantasy': False,
#    'V_try': False,
#    'V_air': False,
#    'V_stupid': False,
#    'V_pure': False,
#    'V_age': False,
#    'V_captures': False,
#    'V_ugly': False,
#    'V_sequences': False,
#    'V_run': False,
#    'V_robert': False,
#    'V_sound': False,
#    'V_inside': False,
#    'V_throughout': False,
#    'V_ii': False,
#    'V_view': False,
#    'V_execution': False,
#    'V_welcome': False,
#    'V_brings': False,
#    'V_subtle': False,
#    'V_suffers': False,
#    'V_school': False,
#    'V_thin': False,
#    'V_scary': False,
#    'V_exciting': False,
#    'V_magic': False,
#    'V_highly': False,
#    'V_pace': False,
#    'V_historical': False,
#    'V_pictures': False,
#    'V_able': False,
#    'V_utterly': False,
#    'V_lovely': False,
#    'V_female': False,
#    'V_based': False,
#    'V_certain': False,
#    'V_fire': False,
#    'V_relationship': False,
#    'V_coming': False,
#    'V_sexual': False,
#    'V_provocative': False,
#    'V_examination': False,
#    'V_sustain': False,
#    'V_creative': False,
#    'V_process': False,
#    'V_alone': False,
#    'V_read': False,
#    'V_deserves': False,
#    'V_ensemble': False,
#    'V_cheap': False,
#    'V_used': False,
#    'V_wants': False,
#    'V_hand': False,
#    'V_memory': False,
#    'V_playing': False,
#    'V_across': False,
#    'V_question': False,
#    'V_major': False,
#    'V_middle': False,
#    'V_chemistry': False,
#    'V_city': False,
#    'V_impact': False,
#    'V_delightful': False,
#    'V_single': False,
#    'V_quickly': False,
#    'V_potential': False,
#    'V_words': False,
#    'V_cartoon': False,
#    'V_working': False,
#    'V_felt': False,
#    'V_tension': False,
#    'V_low': False,
#    'V_cute': False,
#    'V_deal': False,
#    'V_use': False,
#    'V_poignant': False,
#    'V_flaws': False,
#    'V_except': False,
#    'V_upon': False,
#    'V_sentimental': False,
#    'V_waste': False,
#    'V_winning': False,
#    'V_generic': False,
#    'V_flawed': False,
#    'V_actress': False,
#    'V_unfunny': False,
#    'V_master': False,
#    'V_cultural': False,
#    'V_talented': False,
#    'V_mediocre': False,
#    'V_taken': False,
#    'V_creates': False,
#    'V_murder': False,
#    'V_bond': False,
#    'V_success': False,
#    'V_odd': False,
#    'V_force': False,
#    'V_puts': False,
#    'V_unexpected': False,
#    'V_rest': False,
#    'V_lacking': False,
#    'V_situation': False,
#    'V_sensitive': False,
#    'V_stand': False,
#    'V_filled': False,
#    'V_loud': False,
#    'V_yes': False,
#    'V_touch': False,
#    'V_2': False,
#    'V_class': False,
#    'V_heavy': False,
#    'V_surprises': False,
#    'V_formulaic': False,
#    'V_ultimate': False,
#    'V_slight': False,
#    'V_eye': False,
#    'V_melodramatic': False,
#    'V_create': False,
#    'V_extremely': False,
#    'V_house': False,
#    'V_apart': False,
#    'V_unsettling': False,
#    'V_*': False,
#    'V_ability': False,
#    'V_hold': False,
#    'V_era': False,
#    'V_watchable': False,
#    'V_sincere': False,
#    'V_cannot': False,
#    'V_dog': False,
#    'V_issues': False,
#    'V_supposed': False,
#    'V_ago': False,
#    'V_weird': False,
#    'V_convincing': False,
#    'V_routine': False,
#    'V_relationships': False,
#    'V_remember': False,
#    'V_saw': False,
#    'V_giving': False,
#    'V_slightly': False,
#    'V_previous': False,
#    'V_mark': False,
#    'V_cut': False,
#    'V_hell': False,
#    'V_mildly': False,
#    'V_seriously': False,
#    'V_country': False,
#    'V_college': False,
#    'V_hardly': False,
#    'V_reveals': False,
#    'V_fully': False,
#    'V_pop': False,
#    'V_terms': False,
#    'V_artist': False,
#    'V_thrills': False,
#    'V_succeeds': False,
#    'V_date': False,
#    'V_crazy': False,
#    'V_crush': False,
#    'V_contemporary': False,
#    'V_stylish': False,
#    'V_road': False,
#    'V_pleasant': False,
#    'V_sets': False,
#    'V_extreme': False,
#    'V_amount': False,
#    'V_casting': False,
#    'V_pacing': False,
#    'V_finds': False,
#    'V_attempts': False,
#    'V_money': False,
#    'V_twists': False,
#    'V_thinking': False,
#    'V_ones': False,
#    'V_grace': False,
#    'V_george': False,
#    'V_involved': False,
#    'V_forgettable': False,
#    'V_leads': False,
#    'V_tragic': False,
#    'V_five': False,
#    'V_intimate': False,
#    'V_largely': False,
#    'V_joke': False,
#    'V_course': False,
#    'V_episode': False,
#    'V_focus': False,
#    'V_stars': False,
#    'V_uneven': False,
#    'V_indeed': False,
#    'V_gripping': False,
#    'V_inventive': False,
#    'V_old-fashioned': False,
#    'V_plain': False,
#    'V_trouble': False,
#    'V_living': False,
#    'V_treat': False,
#    'V_e': False,
#    'V_steven': False,
#    'V_mix': False,
#    'V_grant': False,
#    'V_happy': False,
#    'V_recommend': False,
#    'V_unique': False,
#    'V_missing': False,
#    'V_absolutely': False,
#    'V_williams': False,
#    'V_runs': False,
#    'V_presents': False,
#    'V_complete': False,
#    'V_happens': False,
#    'V_successful': False,
#    'V_york': False,
#    'V_es': False,
#    'V_masterpiece': False,
#    'V_drag': False,
#    'V_called': False,
#    'V_disturbing': False,
#    'V_promise': False,
#    'V_colorful': False,
#    'V_soundtrack': False,
#    'V_considerable': False,
#    'V_goofy': False,
#    'V_themes': False,
#    'V_painful': False,
#    'V_appears': False,
#    'V_involving': False,
#    'V_heaven': False,
#    'V_badly': False,
#    'V_poetry': False,
#    'V_friendship': False,
#    'V_business': False,
#    'V_substance': False,
#    'V_problems': False,
#    'V_water': False,
#    "V_we've": False,
#    'V_couple': False,
#    'V_blend': False,
#    'V_politics': False,
#    'V_originality': False,
#    'V_forget': False,
#    'V_british': False,
#    'V_typical': False,
#    'V_pieces': False,
#    'V_viewing': False,
#    "V_man's": False,
#    'V_hits': False,
#    'V_wanted': False,
#    'V_person': False,
#    'V_effect': False,
#    'V_bizarre': False,
#    'V_sentimentality': False,
#    'V_urban': False,
#    'V_share': False,
#    'V_target': False,
#    'V_bright': False,
#    'V_evil': False,
#    'V_parts': False,
#    'V_manner': False,
#    'V_gay': False,
#    'V_situations': False,
#    'V_meditation': False,
#    'V_strangely': False,
#    'V_skin': False,
#    'V_mean': False,
#    'V_flicks': False,
#    'V_triumph': False,
#    'V_tom': False,
#    'V_played': False,
#    'V_refreshing': False,
#    'V_oscar': False,
#    'V_loses': False,
#    'V_equally': False,
#    'V_interested': False,
#    'V_terrible': False,
#    'V_forced': False,
#    'V_[a]': False,
#    'V_soul': False,
#    'V_imax': False,
#    'V_somehow': False,
#    'V_absorbing': False,
#    'V_central': False,
#    'V_clichés': False,
#    'V_haunting': False,
#    'V_average': False,
#    "V_director's": False,
#    'V_energetic': False,
#    'V_understand': False,
#    'V_sexy': False,
#    'V_derivative': False,
#    'V_conflict': False,
#    'V_fan': False,
#    'V_alive': False,
#    'V_doubt': False,
#    'V_sophisticated': False,
#    'V_virtually': False,
#    'V_fare': False,
#    'V_report': False,
#    'V_created': False,
#    'V_general': False,
#    'V_well-acted': False,
#    'V_standard': False,
#    'V_said': False,
#    'V_jackson': False,
#    'V_lame': False,
#    'V_company': False,
#    'V_obviously': False,
#    'V_tells': False,
#    'V_fast': False,
#    'V_loss': False,
#    'V_questions': False,
#    'V_means': False,
#    'V_el': False,
#    'V_miss': False,
#    'V_eventually': False,
#    'V_painfully': False,
#    'V_television': False,
#    'V_name': False,
#    'V_night': False,
#    'V_90': False,
#    'V_liked': False,
#    'V_hate': False,
#    'V_grief': False,
#    'V_franchise': False,
#    'V_setting': False,
#    'V_whatever': False,
#    'V_somewhere': False,
#    'V_battle': False,
#    'V_monster': False,
#    'V_frame': False,
#    'V_crafted': False,
#    'V_dry': False,
#    'V_please': False,
#    'V_poor': False,
#    'V_twist': False,
#    'V_word': False,
#    'V_dream': False,
#    'V_depressing': False,
#    'V_stunning': False,
#    'V_vivid': False,
#    'V_wedding': False,
#    'V_amazing': False,
#    'V_remarkably': False,
#    'V_ms': False,
#    'V_toward': False,
#    'V_essentially': False,
#    'V_clearly': False,
#    'V_affecting': False,
#    'V_niro': False,
#    'V_fat': False,
#    'V_worthwhile': False,
#    'V_room': False,
#    'V_thought-provoking': False,
#    'V_blue': False,
#    'V_atmosphere': False,
#    'V_sitting': False,
#    'V_generally': False,
#    'V_finish': False,
#    'V_allows': False,
#    'V_let': False,
#    'V_break': False,
#    'V_imaginative': False,
#    'V_insightful': False,
#    'V_possibly': False,
#    'V_white': False,
#    'V_match': False,
#    'V_unlike': False,
#    'V_price': False,
#    'V_places': False,
#    'V_footage': False,
#    'V_lines': False,
#    'V_opportunity': False,
#    'V_conventional': False,
#    'V_inspired': False,
#    'V_una': False,
#    'V_heavy-handed': False,
#    'V_warmth': False,
#    'V_japanese': False,
#    'V_superficial': False,
#    'V_faith': False,
#    'V_brain': False,
#    'V_riveting': False,
#    'V_slapstick': False,
#    'V_treasure': False,
#    'V_edge': False,
#    'V_lets': False,
#    'V_refreshingly': False,
#    'V_popcorn': False,
#    'V_girls': False,
#    'V_boys': False,
#    'V_excitement': False,
#    'V_deliver': False,
#    'V_genuinely': False,
#    'V_red': False,
#    ...},
#   'neg'),
#  ({'V_.': True,
#    'V_,': False,
#    'V_film': False,
#    'V_movie': True,
#    'V_not': False,
#    'V_one': False,
#    'V_like': False,
#    'V_"': False,
#    'V_--': False,
#    'V_story': False,
#    'V_no': False,
#    'V_much': False,
#    'V_even': False,
#    'V_good': False,
#    'V_comedy': False,
#    'V_time': False,
#    'V_characters': False,
#    'V_little': False,
#    'V_way': False,
#    'V_funny': False,
#    'V_make': False,
#    'V_enough': False,
#    'V_never': False,
#    'V_makes': False,
#    'V_may': False,
#    'V_us': False,
#    'V_work': False,
#    'V_best': False,
#    'V_bad': False,
#    'V_director': False,
#    'V_)': False,
#    'V_?': False,
#    'V_(': False,
#    'V_love': False,
#    'V_would': False,
#    'V_life': False,
#    'V_:': False,
#    'V_movies': False,
#    "V_there's": False,
#    'V_new': False,
#    'V_well': False,
#    'V_could': False,
#    'V_something': False,
#    'V_really': False,
#    'V_made': True,
#    'V_performances': False,
#    "V_that's": False,
#    'V_drama': False,
#    'V_many': False,
#    'V_films': False,
#    'V_look': False,
#    'V_plot': False,
#    'V_still': False,
#    'V_every': False,
#    'V_see': False,
#    'V_two': False,
#    'V_nothing': False,
#    'V_people': False,
#    'V_better': False,
#    'V_without': False,
#    'V_long': False,
#    'V_get': False,
#    'V_fun': False,
#    'V_action': False,
#    'V_great': False,
#    'V_though': False,
#    'V_might': False,
#    'V_big': False,
#    "V_'": False,
#    'V_also': False,
#    'V_another': False,
#    'V_cast': False,
#    'V_humor': False,
#    'V_first': False,
#    'V_kind': False,
#    'V_audience': False,
#    'V_sense': False,
#    'V_ever': False,
#    'V_character': False,
#    'V_feels': False,
#    'V_;': False,
#    'V_performance': False,
#    'V_script': False,
#    "V_film's": False,
#    'V_far': False,
#    'V_often': False,
#    'V_thing': False,
#    'V_less': False,
#    'V_seems': False,
#    'V_minutes': False,
#    'V_real': False,
#    'V_feel': False,
#    'V_picture': False,
#    'V_almost': False,
#    'V_world': False,
#    'V_thriller': False,
#    'V_tale': False,
#    "V_can't": False,
#    'V_documentary': False,
#    'V_quite': False,
#    'V_interesting': False,
#    'V_yet': False,
#    'V_!': False,
#    'V_entertaining': False,
#    'V_rather': False,
#    'V_screen': False,
#    'V_end': False,
#    'V_watching': False,
#    'V_hollywood': False,
#    'V_take': False,
#    'V_seen': False,
#    'V_full': False,
#    'V_ultimately': False,
#    'V_hard': False,
#    'V_go': False,
#    'V_heart': False,
#    'V_romantic': False,
#    'V_de': False,
#    'V_comes': False,
#    'V_moments': False,
#    'V_lot': False,
#    'V_despite': False,
#    'V_american': False,
#    'V_acting': False,
#    'V_family': False,
#    'V_old': False,
#    'V_original': False,
#    'V_find': False,
#    'V_right': False,
#    'V_gets': False,
#    'V_worth': False,
#    'V_human': False,
#    'V_takes': False,
#    'V_come': False,
#    'V_things': False,
#    'V_times': False,
#    'V_dialogue': False,
#    'V_scenes': False,
#    'V_back': False,
#    'V_actors': False,
#    'V_man': False,
#    'V_watch': False,
#    'V_material': True,
#    'V_compelling': False,
#    'V_young': False,
#    'V_music': False,
#    'V_years': False,
#    'V_works': False,
#    'V_emotional': False,
#    'V_think': False,
#    'V_seem': False,
#    'V_anyone': False,
#    'V_want': False,
#    'V_gives': False,
#    'V_least': False,
#    'V_going': False,
#    'V_know': False,
#    'V_say': False,
#    'V_part': False,
#    'V_sometimes': False,
#    'V_piece': False,
#    'V_cinematic': False,
#    'V_entertainment': False,
#    'V_point': False,
#    'V_give': False,
#    'V_subject': False,
#    'V_kids': False,
#    'V_pretty': False,
#    'V_last': False,
#    'V_special': False,
#    'V_bit': False,
#    'V_keep': False,
#    'V_making': False,
#    'V_cinema': False,
#    'V_dull': False,
#    'V_together': False,
#    'V_whole': False,
#    'V_fascinating': False,
#    'V_anything': False,
#    'V_fans': False,
#    'V_year': False,
#    'V_-': False,
#    'V_away': False,
#    'V_moving': False,
#    'V_since': False,
#    'V_style': False,
#    'V_manages': False,
#    'V_need': False,
#    'V_laughs': False,
#    'V_star': False,
#    'V_true': False,
#    'V_show': False,
#    'V_sweet': False,
#    'V_clever': False,
#    'V_experience': False,
#    'V_offers': False,
#    'V_history': False,
#    'V_always': False,
#    'V_direction': False,
#    'V_mr': False,
#    'V_simply': False,
#    'V_high': False,
#    'V_silly': False,
#    'V_instead': False,
#    'V_dark': False,
#    'V_charm': False,
#    'V_whose': False,
#    'V_predictable': False,
#    'V_care': False,
#    'V_actually': False,
#    'V_flick': False,
#    'V_nearly': False,
#    'V_art': False,
#    'V_everything': False,
#    'V_visual': False,
#    'V_series': False,
#    'V_around': False,
#    'V_title': False,
#    'V_matter': False,
#    'V_video': True,
#    'V_place': False,
#    'V_comic': False,
#    'V_narrative': False,
#    "V_he's": False,
#    'V_idea': False,
#    'V_done': False,
#    'V_screenplay': False,
#    'V_goes': False,
#    'V_short': False,
#    'V_war': False,
#    'V_trying': False,
#    'V_women': False,
#    'V_genre': False,
#    'V_probably': False,
#    "V_movie's": False,
#    'V_familiar': False,
#    'V_premise': False,
#    'V_plays': False,
#    'V_horror': False,
#    'V_enjoyable': False,
#    'V_turns': False,
#    'V_three': False,
#    'V_home': False,
#    'V_filmmakers': False,
#    'V_set': False,
#    'V_although': False,
#    'V_becomes': False,
#    'V_engaging': False,
#    'V_lacks': False,
#    'V_worst': False,
#    'V_smart': False,
#    'V_feature': False,
#    'V_feeling': False,
#    'V_enjoy': False,
#    'V_power': False,
#    'V_effects': False,
#    'V_especially': False,
#    'V_ending': False,
#    'V_half': False,
#    'V_study': False,
#    'V_amusing': False,
#    'V_charming': False,
#    'V_effort': False,
#    'V_day': False,
#    'V_intelligent': False,
#    'V_strong': False,
#    'V_boring': False,
#    'V_debut': False,
#    'V_theater': False,
#    'V_lack': False,
#    'V_likely': False,
#    'V_portrait': False,
#    'V_john': False,
#    'V_men': False,
#    'V_romance': False,
#    'V_put': False,
#    'V_version': False,
#    "V_what's": False,
#    'V_certainly': False,
#    'V_sort': False,
#    'V_mostly': False,
#    'V_else': False,
#    'V_beautiful': False,
#    'V_next': False,
#    'V_message': False,
#    'V_problem': False,
#    'V_level': False,
#    'V_looking': False,
#    'V_surprisingly': False,
#    'V_become': False,
#    'V_easy': False,
#    'V_beautifully': False,
#    'V_quirky': False,
#    'V_lives': False,
#    'V_wit': False,
#    'V_hours': False,
#    'V_rare': False,
#    'V_exercise': False,
#    'V_solid': False,
#    'V_along': False,
#    'V_mind': False,
#    'V_play': False,
#    'V_fine': False,
#    'V_looks': False,
#    'V_directed': False,
#    'V_whether': False,
#    'V_fresh': False,
#    'V_sure': False,
#    'V_obvious': False,
#    'V_face': False,
#    'V_ideas': False,
#    'V_mess': False,
#    'V_leave': False,
#    'V_completely': False,
#    'V_modern': False,
#    'V_french': False,
#    'V_either': False,
#    'V_powerful': False,
#    'V_past': False,
#    'V_interest': False,
#    'V_energy': False,
#    'V_neither': False,
#    'V_melodrama': False,
#    'V_viewers': False,
#    'V_dramatic': False,
#    'V_beyond': False,
#    'V_shot': False,
#    'V_classic': False,
#    'V_fact': False,
#    'V_reason': False,
#    'V_recent': False,
#    'V_children': False,
#    'V_filmmaking': False,
#    'V_delivers': False,
#    'V_shows': False,
#    'V_tone': False,
#    'V_suspense': False,
#    'V_fails': False,
#    'V_stuff': False,
#    'V_culture': False,
#    "V_i'm": False,
#    'V_truly': False,
#    'V_deeply': False,
#    'V_believe': False,
#    'V_everyone': False,
#    'V_left': False,
#    'V_intriguing': False,
#    'V_slow': False,
#    'V_ends': False,
#    'V_death': False,
#    'V_actor': False,
#    'V_jokes': False,
#    'V_serious': False,
#    'V_book': False,
#    'V_tries': False,
#    'V_black': False,
#    'V_ride': False,
#    'V_occasionally': False,
#    'V_small': False,
#    'V_spirit': False,
#    'V_sad': False,
#    'V_production': False,
#    'V_audiences': False,
#    'V_tv': False,
#    'V_touching': False,
#    'V_light': False,
#    'V_formula': False,
#    'V_camera': False,
#    'V_hilarious': False,
#    'V_role': False,
#    'V_exactly': False,
#    'V_terrific': False,
#    'V_proves': False,
#    'V_remains': False,
#    'V_satisfying': False,
#    'V_opera': False,
#    'V_passion': False,
#    'V_storytelling': False,
#    'V_dumb': False,
#    'V_reality': False,
#    'V_adventure': False,
#    'V_must': False,
#    'V_project': False,
#    'V_filmmaker': False,
#    'V_nor': False,
#    'V_seeing': False,
#    'V_images': False,
#    'V_already': False,
#    'V_got': False,
#    'V_different': False,
#    'V_line': False,
#    'V_talent': False,
#    'V_stories': False,
#    'V_impossible': False,
#    'V_scene': False,
#    'V_perfect': False,
#    'V_journey': False,
#    'V_girl': False,
#    'V_gags': False,
#    'V_attempt': False,
#    'V_personal': False,
#    'V_simple': False,
#    'V_particularly': False,
#    'V_easily': False,
#    'V_turn': False,
#    'V_close': False,
#    'V_summer': False,
#    'V_pleasure': False,
#    'V_given': False,
#    'V_psychological': False,
#    'V_animation': False,
#    'V_complex': False,
#    'V_sex': False,
#    'V_pretentious': False,
#    'V_honest': False,
#    'V_hour': False,
#    'V_flat': False,
#    'V_case': False,
#    'V_ways': False,
#    'V_found': False,
#    'V_falls': False,
#    'V_michael': False,
#    'V_intelligence': False,
#    'V_earnest': False,
#    'V_difficult': False,
#    'V_head': False,
#    'V_cliches': False,
#    'V_political': False,
#    'V_mystery': False,
#    'V_visually': False,
#    'V_sequel': False,
#    'V_getting': False,
#    'V_leaves': False,
#    'V_social': False,
#    'V_coming-of-age': False,
#    'V_thought': False,
#    'V_game': True,
#    'V_uses': False,
#    'V_violence': False,
#    'V_none': False,
#    'V_que': False,
#    'V_memorable': False,
#    'V_written': False,
#    'V_crime': False,
#    'V_writing': False,
#    'V_tell': False,
#    'V_gone': False,
#    'V_wrong': False,
#    'V_keeps': False,
#    'V_rich': False,
#    'V_help': False,
#    'V_brilliant': False,
#    'V_side': False,
#    'V_laugh': False,
#    'V_job': False,
#    'V_told': False,
#    'V_overall': False,
#    'V_satire': False,
#    'V_live': False,
#    'V_finally': False,
#    'V_contrived': False,
#    'V_needs': False,
#    'V_spy': False,
#    'V_days': False,
#    'V_novel': False,
#    'V_barely': False,
#    'V_lost': False,
#    'V_rarely': False,
#    'V_otherwise': False,
#    'V_second': False,
#    'V_elements': False,
#    'V_cold': False,
#    'V_boy': False,
#    'V_cool': False,
#    'V_final': False,
#    'V_starts': False,
#    'V_possible': False,
#    'V_nature': False,
#    'V_entirely': False,
#    'V_guys': False,
#    'V_taste': False,
#    'V_several': False,
#    'V_imagine': False,
#    'V_appeal': False,
#    'V_acted': False,
#    'V_approach': False,
#    'V_thoughtful': False,
#    'V_wonderful': False,
#    'V_fairly': False,
#    'V_excellent': False,
#    'V_warm': False,
#    'V_running': False,
#    'V_eyes': False,
#    'V_tragedy': False,
#    'V_insight': False,
#    'V_concept': False,
#    'V_creepy': False,
#    'V_moral': False,
#    'V_surprising': False,
#    'V_act': False,
#    'V_lead': False,
#    'V_wild': False,
#    'V_truth': False,
#    'V_mood': False,
#    'V_soap': False,
#    'V_perhaps': False,
#    'V_behind': False,
#    'V_comedies': False,
#    'V_among': False,
#    'V_form': False,
#    'V_quality': False,
#    'V_others': False,
#    'V_viewer': False,
#    'V_engrossing': False,
#    'V_expect': False,
#    "V_they're": False,
#    'V_tedious': False,
#    'V_thoroughly': False,
#    'V_attention': False,
#    'V_result': False,
#    'V_call': False,
#    'V_david': False,
#    'V_bring': False,
#    'V_remarkable': False,
#    'V_hero': False,
#    'V_imagination': False,
#    'V_emotionally': False,
#    'V_entire': False,
#    'V_adults': False,
#    'V_sci-fi': False,
#    'V_gorgeous': False,
#    'V_\x96': False,
#    'V_strange': False,
#    'V_add': False,
#    'V_moment': False,
#    'V_remake': False,
#    'V_adaptation': False,
#    'V_usual': False,
#    "V_i've": False,
#    'V_teen': False,
#    'V_change': False,
#    'V_start': False,
#    'V_genuine': False,
#    'V_future': False,
#    'V_nice': False,
#    'V_tired': False,
#    'V_knows': False,
#    'V_perfectly': False,
#    'V_latest': False,
#    'V_animated': False,
#    'V_sharp': False,
#    'V_disney': False,
#    'V_rock': False,
#    'V_vision': False,
#    'V_quiet': False,
#    'V_witty': False,
#    'V_bland': False,
#    'V_four': False,
#    'V_epic': False,
#    'V_la': False,
#    'V_points': False,
#    'V_parents': False,
#    'V_depth': False,
#    'V_period': False,
#    'V_impressive': False,
#    'V_maybe': False,
#    'V_gentle': False,
#    'V_plenty': False,
#    'V_beauty': False,
#    'V_worse': False,
#    'V_events': False,
#    'V_taking': False,
#    'V_begins': False,
#    'V_effective': False,
#    'V_merely': False,
#    'V_thanks': False,
#    'V_hope': False,
#    'V_wonder': False,
#    'V_somewhat': False,
#    'V_appealing': False,
#    'V_deep': False,
#    'V_dead': False,
#    'V_worthy': False,
#    'V_offer': False,
#    'V_clear': True,
#    'V_surprise': False,
#    'V_awful': False,
#    'V_sit': False,
#    'V_writer-director': False,
#    'V_emotions': False,
#    'V_important': False,
#    'V_lots': False,
#    'V_decent': False,
#    'V_ambitious': False,
#    'V_straight': False,
#    'V_hit': False,
#    'V_however': False,
#    'V_guy': False,
#    "V_year's": False,
#    'V_provides': False,
#    'V_woman': False,
#    'V_definitely': False,
#    'V_unfortunately': False,
#    'V_someone': False,
#    'V_career': False,
#    'V_fantasy': False,
#    'V_try': False,
#    'V_air': False,
#    'V_stupid': False,
#    'V_pure': False,
#    'V_age': False,
#    'V_captures': False,
#    'V_ugly': False,
#    'V_sequences': False,
#    'V_run': False,
#    'V_robert': False,
#    'V_sound': False,
#    'V_inside': False,
#    'V_throughout': False,
#    'V_ii': False,
#    'V_view': False,
#    'V_execution': False,
#    'V_welcome': False,
#    'V_brings': False,
#    'V_subtle': False,
#    'V_suffers': False,
#    'V_school': False,
#    'V_thin': False,
#    'V_scary': False,
#    'V_exciting': False,
#    'V_magic': False,
#    'V_highly': False,
#    'V_pace': False,
#    'V_historical': False,
#    'V_pictures': False,
#    'V_able': False,
#    'V_utterly': False,
#    'V_lovely': False,
#    'V_female': False,
#    'V_based': False,
#    'V_certain': False,
#    'V_fire': False,
#    'V_relationship': False,
#    'V_coming': False,
#    'V_sexual': False,
#    'V_provocative': False,
#    'V_examination': False,
#    'V_sustain': False,
#    'V_creative': False,
#    'V_process': False,
#    'V_alone': False,
#    'V_read': False,
#    'V_deserves': False,
#    'V_ensemble': False,
#    'V_cheap': False,
#    'V_used': False,
#    'V_wants': False,
#    'V_hand': False,
#    'V_memory': False,
#    'V_playing': False,
#    'V_across': False,
#    'V_question': False,
#    'V_major': False,
#    'V_middle': False,
#    'V_chemistry': False,
#    'V_city': False,
#    'V_impact': False,
#    'V_delightful': False,
#    'V_single': False,
#    'V_quickly': False,
#    'V_potential': False,
#    'V_words': False,
#    'V_cartoon': False,
#    'V_working': False,
#    'V_felt': False,
#    'V_tension': False,
#    'V_low': False,
#    'V_cute': False,
#    'V_deal': False,
#    'V_use': False,
#    'V_poignant': False,
#    'V_flaws': False,
#    'V_except': False,
#    'V_upon': False,
#    'V_sentimental': False,
#    'V_waste': False,
#    'V_winning': False,
#    'V_generic': False,
#    'V_flawed': False,
#    'V_actress': False,
#    'V_unfunny': False,
#    'V_master': False,
#    'V_cultural': False,
#    'V_talented': False,
#    'V_mediocre': False,
#    'V_taken': False,
#    'V_creates': False,
#    'V_murder': False,
#    'V_bond': False,
#    'V_success': False,
#    'V_odd': False,
#    'V_force': False,
#    'V_puts': False,
#    'V_unexpected': False,
#    'V_rest': False,
#    'V_lacking': False,
#    'V_situation': False,
#    'V_sensitive': False,
#    'V_stand': False,
#    'V_filled': False,
#    'V_loud': False,
#    'V_yes': False,
#    'V_touch': False,
#    'V_2': False,
#    'V_class': False,
#    'V_heavy': False,
#    'V_surprises': False,
#    'V_formulaic': False,
#    'V_ultimate': False,
#    'V_slight': False,
#    'V_eye': False,
#    'V_melodramatic': False,
#    'V_create': False,
#    'V_extremely': False,
#    'V_house': False,
#    'V_apart': False,
#    'V_unsettling': False,
#    'V_*': False,
#    'V_ability': False,
#    'V_hold': False,
#    'V_era': False,
#    'V_watchable': False,
#    'V_sincere': False,
#    'V_cannot': False,
#    'V_dog': False,
#    'V_issues': False,
#    'V_supposed': False,
#    'V_ago': False,
#    'V_weird': False,
#    'V_convincing': False,
#    'V_routine': False,
#    'V_relationships': False,
#    'V_remember': False,
#    'V_saw': False,
#    'V_giving': False,
#    'V_slightly': False,
#    'V_previous': False,
#    'V_mark': False,
#    'V_cut': False,
#    'V_hell': False,
#    'V_mildly': False,
#    'V_seriously': False,
#    'V_country': False,
#    'V_college': False,
#    'V_hardly': False,
#    'V_reveals': False,
#    'V_fully': False,
#    'V_pop': False,
#    'V_terms': False,
#    'V_artist': False,
#    'V_thrills': False,
#    'V_succeeds': False,
#    'V_date': False,
#    'V_crazy': False,
#    'V_crush': False,
#    'V_contemporary': False,
#    'V_stylish': False,
#    'V_road': False,
#    'V_pleasant': False,
#    'V_sets': False,
#    'V_extreme': False,
#    'V_amount': False,
#    'V_casting': False,
#    'V_pacing': False,
#    'V_finds': False,
#    'V_attempts': False,
#    'V_money': False,
#    'V_twists': False,
#    'V_thinking': False,
#    'V_ones': False,
#    'V_grace': False,
#    'V_george': False,
#    'V_involved': False,
#    'V_forgettable': False,
#    'V_leads': False,
#    'V_tragic': False,
#    'V_five': False,
#    'V_intimate': False,
#    'V_largely': False,
#    'V_joke': False,
#    'V_course': False,
#    'V_episode': False,
#    'V_focus': False,
#    'V_stars': False,
#    'V_uneven': False,
#    'V_indeed': False,
#    'V_gripping': False,
#    'V_inventive': False,
#    'V_old-fashioned': False,
#    'V_plain': False,
#    'V_trouble': False,
#    'V_living': False,
#    'V_treat': False,
#    'V_e': False,
#    'V_steven': False,
#    'V_mix': False,
#    'V_grant': False,
#    'V_happy': False,
#    'V_recommend': False,
#    'V_unique': False,
#    'V_missing': False,
#    'V_absolutely': False,
#    'V_williams': False,
#    'V_runs': False,
#    'V_presents': False,
#    'V_complete': False,
#    'V_happens': False,
#    'V_successful': False,
#    'V_york': False,
#    'V_es': False,
#    'V_masterpiece': False,
#    'V_drag': False,
#    'V_called': False,
#    'V_disturbing': False,
#    'V_promise': False,
#    'V_colorful': False,
#    'V_soundtrack': False,
#    'V_considerable': False,
#    'V_goofy': False,
#    'V_themes': False,
#    'V_painful': False,
#    'V_appears': False,
#    'V_involving': False,
#    'V_heaven': False,
#    'V_badly': False,
#    'V_poetry': False,
#    'V_friendship': False,
#    'V_business': False,
#    'V_substance': False,
#    'V_problems': False,
#    'V_water': False,
#    "V_we've": False,
#    'V_couple': False,
#    'V_blend': False,
#    'V_politics': False,
#    'V_originality': False,
#    'V_forget': False,
#    'V_british': False,
#    'V_typical': False,
#    'V_pieces': False,
#    'V_viewing': False,
#    "V_man's": False,
#    'V_hits': False,
#    'V_wanted': False,
#    'V_person': False,
#    'V_effect': False,
#    'V_bizarre': False,
#    'V_sentimentality': False,
#    'V_urban': False,
#    'V_share': False,
#    'V_target': False,
#    'V_bright': False,
#    'V_evil': False,
#    'V_parts': False,
#    'V_manner': False,
#    'V_gay': False,
#    'V_situations': False,
#    'V_meditation': False,
#    'V_strangely': False,
#    'V_skin': False,
#    'V_mean': False,
#    'V_flicks': False,
#    'V_triumph': False,
#    'V_tom': False,
#    'V_played': False,
#    'V_refreshing': False,
#    'V_oscar': False,
#    'V_loses': False,
#    'V_equally': False,
#    'V_interested': False,
#    'V_terrible': False,
#    'V_forced': False,
#    'V_[a]': False,
#    'V_soul': False,
#    'V_imax': False,
#    'V_somehow': False,
#    'V_absorbing': False,
#    'V_central': False,
#    'V_clichés': False,
#    'V_haunting': False,
#    'V_average': False,
#    "V_director's": False,
#    'V_energetic': False,
#    'V_understand': False,
#    'V_sexy': False,
#    'V_derivative': False,
#    'V_conflict': False,
#    'V_fan': False,
#    'V_alive': False,
#    'V_doubt': False,
#    'V_sophisticated': False,
#    'V_virtually': False,
#    'V_fare': False,
#    'V_report': False,
#    'V_created': False,
#    'V_general': False,
#    'V_well-acted': False,
#    'V_standard': False,
#    'V_said': False,
#    'V_jackson': False,
#    'V_lame': False,
#    'V_company': False,
#    'V_obviously': False,
#    'V_tells': False,
#    'V_fast': False,
#    'V_loss': False,
#    'V_questions': False,
#    'V_means': False,
#    'V_el': False,
#    'V_miss': False,
#    'V_eventually': False,
#    'V_painfully': False,
#    'V_television': False,
#    'V_name': False,
#    'V_night': False,
#    'V_90': False,
#    'V_liked': False,
#    'V_hate': False,
#    'V_grief': False,
#    'V_franchise': False,
#    'V_setting': False,
#    'V_whatever': False,
#    'V_somewhere': False,
#    'V_battle': False,
#    'V_monster': False,
#    'V_frame': False,
#    'V_crafted': False,
#    'V_dry': False,
#    'V_please': False,
#    'V_poor': False,
#    'V_twist': False,
#    'V_word': False,
#    'V_dream': False,
#    'V_depressing': False,
#    'V_stunning': False,
#    'V_vivid': False,
#    'V_wedding': False,
#    'V_amazing': False,
#    'V_remarkably': False,
#    'V_ms': False,
#    'V_toward': False,
#    'V_essentially': False,
#    'V_clearly': False,
#    'V_affecting': False,
#    'V_niro': False,
#    'V_fat': False,
#    'V_worthwhile': False,
#    'V_room': False,
#    'V_thought-provoking': False,
#    'V_blue': False,
#    'V_atmosphere': False,
#    'V_sitting': False,
#    'V_generally': False,
#    'V_finish': False,
#    'V_allows': False,
#    'V_let': False,
#    'V_break': False,
#    'V_imaginative': False,
#    'V_insightful': False,
#    'V_possibly': False,
#    'V_white': False,
#    'V_match': False,
#    'V_unlike': False,
#    'V_price': False,
#    'V_places': False,
#    'V_footage': False,
#    'V_lines': False,
#    'V_opportunity': False,
#    'V_conventional': False,
#    'V_inspired': False,
#    'V_una': False,
#    'V_heavy-handed': False,
#    'V_warmth': False,
#    'V_japanese': False,
#    'V_superficial': False,
#    'V_faith': False,
#    'V_brain': False,
#    'V_riveting': False,
#    'V_slapstick': False,
#    'V_treasure': False,
#    'V_edge': False,
#    'V_lets': False,
#    'V_refreshingly': False,
#    'V_popcorn': False,
#    'V_girls': False,
#    'V_boys': False,
#    'V_excitement': False,
#    'V_deliver': False,
#    'V_genuinely': False,
#    'V_red': False,
#    ...},
#   'neg'),
#  ({'V_.': True,
#    'V_,': True,
#    'V_film': False,
#    'V_movie': False,
#    'V_not': False,
#    'V_one': False,
#    'V_like': False,
#    'V_"': False,
#    'V_--': False,
#    'V_story': False,
#    'V_no': False,
#    'V_much': False,
#    'V_even': False,
#    'V_good': True,
#    'V_comedy': True,
#    'V_time': False,
#    'V_characters': False,
#    'V_little': False,
#    'V_way': False,
#    'V_funny': False,
#    'V_make': False,
#    'V_enough': False,
#    'V_never': False,
#    'V_makes': False,
#    'V_may': False,
#    'V_us': False,
#    'V_work': False,
#    'V_best': False,
#    'V_bad': False,
#    'V_director': False,
#    'V_)': False,
#    'V_?': False,
#    'V_(': False,
#    'V_love': False,
#    'V_would': False,
#    'V_life': False,
#    'V_:': False,
#    'V_movies': False,
#    "V_there's": False,
#    'V_new': False,
#    'V_well': False,
#    'V_could': False,
#    'V_something': False,
#    'V_really': False,
#    'V_made': False,
#    'V_performances': False,
#    "V_that's": False,
#    'V_drama': False,
#    'V_many': False,
#    'V_films': False,
#    'V_look': False,
#    'V_plot': False,
#    'V_still': False,
#    'V_every': False,
#    'V_see': False,
#    'V_two': False,
#    'V_nothing': False,
#    'V_people': False,
#    'V_better': False,
#    'V_without': False,
#    'V_long': False,
#    'V_get': False,
#    'V_fun': False,
#    'V_action': False,
#    'V_great': False,
#    'V_though': False,
#    'V_might': False,
#    'V_big': False,
#    "V_'": False,
#    'V_also': False,
#    'V_another': False,
#    'V_cast': False,
#    'V_humor': False,
#    'V_first': False,
#    'V_kind': False,
#    'V_audience': False,
#    'V_sense': False,
#    'V_ever': False,
#    'V_character': False,
#    'V_feels': False,
#    'V_;': False,
#    'V_performance': False,
#    'V_script': False,
#    "V_film's": False,
#    'V_far': False,
#    'V_often': False,
#    'V_thing': False,
#    'V_less': False,
#    'V_seems': False,
#    'V_minutes': False,
#    'V_real': False,
#    'V_feel': False,
#    'V_picture': False,
#    'V_almost': False,
#    'V_world': False,
#    'V_thriller': False,
#    'V_tale': False,
#    "V_can't": False,
#    'V_documentary': False,
#    'V_quite': False,
#    'V_interesting': False,
#    'V_yet': False,
#    'V_!': False,
#    'V_entertaining': False,
#    'V_rather': False,
#    'V_screen': False,
#    'V_end': False,
#    'V_watching': False,
#    'V_hollywood': False,
#    'V_take': False,
#    'V_seen': False,
#    'V_full': False,
#    'V_ultimately': False,
#    'V_hard': False,
#    'V_go': False,
#    'V_heart': False,
#    'V_romantic': False,
#    'V_de': False,
#    'V_comes': False,
#    'V_moments': False,
#    'V_lot': False,
#    'V_despite': False,
#    'V_american': False,
#    'V_acting': True,
#    'V_family': False,
#    'V_old': False,
#    'V_original': False,
#    'V_find': False,
#    'V_right': False,
#    'V_gets': False,
#    'V_worth': False,
#    'V_human': False,
#    'V_takes': False,
#    'V_come': False,
#    'V_things': False,
#    'V_times': False,
#    'V_dialogue': True,
#    'V_scenes': False,
#    'V_back': False,
#    'V_actors': False,
#    'V_man': False,
#    'V_watch': False,
#    'V_material': False,
#    'V_compelling': False,
#    'V_young': False,
#    'V_music': False,
#    'V_years': False,
#    'V_works': False,
#    'V_emotional': False,
#    'V_think': False,
#    'V_seem': False,
#    'V_anyone': False,
#    'V_want': False,
#    'V_gives': False,
#    'V_least': False,
#    'V_going': False,
#    'V_know': False,
#    'V_say': False,
#    'V_part': False,
#    'V_sometimes': False,
#    'V_piece': False,
#    'V_cinematic': False,
#    'V_entertainment': False,
#    'V_point': False,
#    'V_give': False,
#    'V_subject': False,
#    'V_kids': False,
#    'V_pretty': False,
#    'V_last': False,
#    'V_special': False,
#    'V_bit': False,
#    'V_keep': False,
#    'V_making': False,
#    'V_cinema': False,
#    'V_dull': False,
#    'V_together': False,
#    'V_whole': False,
#    'V_fascinating': False,
#    'V_anything': False,
#    'V_fans': False,
#    'V_year': False,
# ...
#    'V_problem': False,
#    'V_level': False,
#    'V_looking': False,
#    'V_surprisingly': False,
#    'V_become': False,
#    'V_easy': False,
#    'V_beautifully': False,
#    'V_quirky': False,
#    'V_lives': False,
#    'V_wit': False,
#    'V_hours': False,
#    'V_rare': False,
#    'V_exercise': False,
#    'V_solid': False,
#    'V_along': False,
#    'V_mind': False,
#    'V_play': False,
#    'V_fine': False,
#    'V_looks': False,
#    'V_directed': False,
#    'V_whether': False,
#    'V_fresh': False,
#    'V_sure': False,
#    'V_obvious': False,
#    'V_face': False,
#    'V_ideas': False,
#    'V_mess': False,
#    'V_leave': False,
#    'V_completely': False,
#    'V_modern': False,
#    'V_french': False,
#    'V_either': False,
#    'V_powerful': False,
#    'V_past': False,
#    'V_interest': False,
#    'V_energy': False,
#    'V_neither': False,
#    'V_melodrama': False,
#    'V_viewers': False,
#    'V_dramatic': False,
#    'V_beyond': False,
#    'V_shot': False,
#    'V_classic': False,
#    'V_fact': False,
#    'V_reason': False,
#    'V_recent': False,
#    'V_children': False,
#    'V_filmmaking': False,
#    'V_delivers': False,
#    'V_shows': False,
#    'V_tone': False,
#    'V_suspense': False,
#    'V_fails': False,
#    'V_stuff': False,
#    'V_culture': False,
#    "V_i'm": False,
#    'V_truly': False,
#    'V_deeply': False,
#    'V_believe': False,
#    'V_everyone': False,
#    'V_left': False,
#    'V_intriguing': False,
#    'V_slow': False,
#    'V_ends': False,
#    'V_death': False,
#    'V_actor': False,
#    'V_jokes': False,
#    'V_serious': False,
#    'V_book': False,
#    'V_tries': False,
#    'V_black': False,
#    'V_ride': False,
#    'V_occasionally': False,
#    'V_small': False,
#    'V_spirit': False,
#    'V_sad': False,
#    'V_production': False,
#    'V_audiences': False,
#    'V_tv': False,
#    'V_touching': False,
#    'V_light': False,
#    'V_formula': False,
#    'V_camera': False,
#    'V_hilarious': False,
#    'V_role': False,
#    'V_exactly': False,
#    'V_terrific': False,
#    'V_proves': False,
#    'V_remains': False,
#    'V_satisfying': False,
#    'V_opera': False,
#    'V_passion': False,
#    'V_storytelling': False,
#    'V_dumb': False,
#    'V_reality': False,
#    'V_adventure': False,
#    'V_must': False,
#    'V_project': False,
#    'V_filmmaker': False,
#    'V_nor': False,
#    'V_seeing': False,
#    'V_images': False,
#    'V_already': False,
#    'V_got': False,
#    'V_different': False,
#    'V_line': False,
#    'V_talent': False,
#    'V_stories': False,
#    'V_impossible': False,
#    'V_scene': False,
#    'V_perfect': False,
#    'V_journey': False,
#    'V_girl': False,
#    'V_gags': False,
#    'V_attempt': False,
#    'V_personal': False,
#    'V_simple': False,
#    'V_particularly': False,
#    'V_easily': False,
#    'V_turn': False,
#    'V_close': False,
#    'V_summer': False,
#    'V_pleasure': False,
#    'V_given': False,
#    'V_psychological': False,
#    'V_animation': False,
#    'V_complex': False,
#    'V_sex': False,
#    'V_pretentious': False,
#    'V_honest': False,
#    'V_hour': False,
#    'V_flat': False,
#    'V_case': False,
#    'V_ways': False,
#    'V_found': False,
#    'V_falls': False,
#    'V_michael': False,
#    'V_intelligence': False,
#    'V_earnest': False,
#    'V_difficult': False,
#    'V_head': False,
#    'V_cliches': False,
#    'V_political': False,
#    'V_mystery': False,
#    'V_visually': False,
#    'V_sequel': False,
#    'V_getting': False,
#    'V_leaves': False,
#    'V_social': False,
#    'V_coming-of-age': False,
#    'V_thought': False,
#    'V_game': False,
#    'V_uses': False,
#    'V_violence': False,
#    'V_none': False,
#    'V_que': False,
#    'V_memorable': False,
#    'V_written': False,
#    'V_crime': False,
#    'V_writing': False,
#    'V_tell': False,
#    'V_gone': False,
#    'V_wrong': False,
#    'V_keeps': False,
#    'V_rich': False,
#    'V_help': False,
#    'V_brilliant': False,
#    'V_side': False,
#    'V_laugh': False,
#    'V_job': False,
#    'V_told': False,
#    'V_overall': False,
#    'V_satire': False,
#    'V_live': False,
#    'V_finally': False,
#    'V_contrived': False,
#    'V_needs': False,
#    'V_spy': False,
#    'V_days': False,
#    'V_novel': False,
#    'V_barely': False,
#    'V_lost': False,
#    'V_rarely': False,
#    'V_otherwise': False,
#    'V_second': False,
#    'V_elements': False,
#    'V_cold': False,
#    'V_boy': False,
#    'V_cool': False,
#    'V_final': False,
#    'V_starts': False,
#    'V_possible': False,
#    'V_nature': False,
#    'V_entirely': False,
#    'V_guys': False,
#    'V_taste': False,
#    'V_several': False,
#    'V_imagine': False,
#    'V_appeal': False,
#    'V_acted': False,
#    'V_approach': False,
#    'V_thoughtful': False,
#    'V_wonderful': False,
#    'V_fairly': False,
#    'V_excellent': False,
#    'V_warm': False,
#    'V_running': False,
#    'V_eyes': False,
#    'V_tragedy': False,
#    'V_insight': False,
#    'V_concept': False,
#    'V_creepy': False,
#    'V_moral': False,
#    'V_surprising': False,
#    'V_act': False,
#    'V_lead': False,
#    'V_wild': False,
#    'V_truth': False,
#    'V_mood': False,
#    'V_soap': False,
#    'V_perhaps': False,
#    'V_behind': False,
#    'V_comedies': False,
#    'V_among': False,
#    'V_form': False,
#    'V_quality': False,
#    'V_others': False,
#    'V_viewer': False,
#    'V_engrossing': False,
#    'V_expect': False,
#    "V_they're": False,
#    'V_tedious': False,
#    'V_thoroughly': False,
#    'V_attention': False,
#    'V_result': False,
#    'V_call': False,
#    'V_david': False,
#    'V_bring': False,
#    'V_remarkable': False,
#    'V_hero': False,
#    'V_imagination': False,
#    'V_emotionally': False,
#    'V_entire': False,
#    'V_adults': False,
#    'V_sci-fi': False,
#    'V_gorgeous': False,
#    'V_\x96': False,
#    'V_strange': False,
#    'V_add': False,
#    'V_moment': False,
#    'V_remake': False,
#    'V_adaptation': False,
#    'V_usual': False,
#    "V_i've": False,
#    'V_teen': False,
#    'V_change': False,
#    'V_start': False,
#    'V_genuine': False,
#    'V_future': False,
#    'V_nice': False,
#    'V_tired': False,
#    'V_knows': False,
#    'V_perfectly': False,
#    'V_latest': False,
#    'V_animated': False,
#    'V_sharp': False,
#    'V_disney': False,
#    'V_rock': False,
#    'V_vision': False,
#    'V_quiet': False,
#    'V_witty': False,
#    'V_bland': False,
#    'V_four': False,
#    'V_epic': False,
#    'V_la': False,
#    'V_points': False,
#    'V_parents': False,
#    'V_depth': False,
#    'V_period': False,
#    'V_impressive': False,
#    'V_maybe': False,
#    'V_gentle': False,
#    'V_plenty': False,
#    'V_beauty': False,
#    'V_worse': False,
#    'V_events': False,
#    'V_taking': False,
#    'V_begins': False,
#    'V_effective': False,
#    'V_merely': False,
#    'V_thanks': False,
#    'V_hope': False,
#    'V_wonder': False,
#    'V_somewhat': False,
#    'V_appealing': False,
#    'V_deep': False,
#    'V_dead': False,
#    'V_worthy': False,
#    'V_offer': False,
#    'V_clear': False,
#    'V_surprise': False,
#    'V_awful': False,
#    'V_sit': False,
#    'V_writer-director': False,
#    'V_emotions': False,
#    'V_important': False,
#    'V_lots': False,
#    'V_decent': False,
#    'V_ambitious': False,
#    'V_straight': False,
#    'V_hit': False,
#    'V_however': False,
#    'V_guy': False,
#    "V_year's": False,
#    'V_provides': False,
#    'V_woman': False,
#    'V_definitely': False,
#    'V_unfortunately': False,
#    'V_someone': False,
#    'V_career': False,
#    'V_fantasy': False,
#    'V_try': False,
#    'V_air': False,
#    'V_stupid': False,
#    'V_pure': False,
#    'V_age': False,
#    'V_captures': False,
#    'V_ugly': False,
#    'V_sequences': False,
#    'V_run': False,
#    'V_robert': False,
#    'V_sound': False,
#    'V_inside': False,
#    'V_throughout': False,
#    'V_ii': False,
#    'V_view': False,
#    'V_execution': False,
#    'V_welcome': False,
#    'V_brings': False,
#    'V_subtle': False,
#    'V_suffers': False,
#    'V_school': False,
#    'V_thin': False,
#    'V_scary': False,
#    'V_exciting': False,
#    'V_magic': False,
#    'V_highly': False,
#    'V_pace': False,
#    'V_historical': False,
#    'V_pictures': False,
#    'V_able': False,
#    'V_utterly': False,
#    'V_lovely': False,
#    'V_female': False,
#    'V_based': False,
#    'V_certain': False,
#    'V_fire': False,
#    'V_relationship': False,
#    'V_coming': False,
#    'V_sexual': False,
#    'V_provocative': False,
#    'V_examination': False,
#    'V_sustain': False,
#    'V_creative': False,
#    'V_process': False,
#    'V_alone': False,
#    'V_read': False,
#    'V_deserves': False,
#    'V_ensemble': False,
#    'V_cheap': False,
#    'V_used': False,
#    'V_wants': False,
#    'V_hand': False,
#    'V_memory': False,
#    'V_playing': False,
#    'V_across': False,
#    'V_question': False,
#    'V_major': False,
#    'V_middle': False,
#    'V_chemistry': False,
#    'V_city': False,
#    'V_impact': False,
#    'V_delightful': False,
#    'V_single': False,
#    'V_quickly': False,
#    'V_potential': False,
#    'V_words': False,
#    'V_cartoon': False,
#    'V_working': False,
#    'V_felt': False,
#    'V_tension': False,
#    'V_low': False,
#    'V_cute': False,
#    'V_deal': False,
#    'V_use': False,
#    'V_poignant': False,
#    'V_flaws': False,
#    'V_except': False,
#    'V_upon': False,
#    'V_sentimental': False,
#    'V_waste': False,
#    'V_winning': False,
#    'V_generic': False,
#    'V_flawed': False,
#    'V_actress': False,
#    'V_unfunny': False,
#    'V_master': False,
#    'V_cultural': False,
#    'V_talented': False,
#    'V_mediocre': False,
#    'V_taken': False,
#    'V_creates': False,
#    'V_murder': False,
#    'V_bond': False,
#    'V_success': False,
#    'V_odd': False,
#    'V_force': False,
#    'V_puts': False,
#    'V_unexpected': False,
#    'V_rest': False,
#    'V_lacking': False,
#    'V_situation': False,
#    'V_sensitive': False,
#    'V_stand': False,
#    'V_filled': False,
#    'V_loud': False,
#    'V_yes': False,
#    'V_touch': False,
#    'V_2': False,
#    'V_class': False,
#    'V_heavy': False,
#    'V_surprises': False,
#    'V_formulaic': False,
#    'V_ultimate': False,
#    'V_slight': False,
#    'V_eye': False,
#    'V_melodramatic': False,
#    'V_create': False,
#    'V_extremely': False,
#    'V_house': False,
#    'V_apart': False,
#    'V_unsettling': False,
#    'V_*': False,
#    'V_ability': False,
#    'V_hold': False,
#    'V_era': False,
#    'V_watchable': False,
#    'V_sincere': False,
#    'V_cannot': False,
#    'V_dog': False,
#    'V_issues': False,
#    'V_supposed': False,
#    'V_ago': False,
#    'V_weird': False,
#    'V_convincing': False,
#    'V_routine': False,
#    'V_relationships': False,
#    'V_remember': False,
#    'V_saw': False,
#    'V_giving': False,
#    'V_slightly': False,
#    'V_previous': False,
#    'V_mark': False,
#    'V_cut': False,
#    'V_hell': False,
#    'V_mildly': False,
#    'V_seriously': False,
#    'V_country': False,
#    'V_college': False,
#    'V_hardly': False,
#    'V_reveals': False,
#    'V_fully': False,
#    'V_pop': False,
#    'V_terms': False,
#    'V_artist': False,
#    'V_thrills': False,
#    'V_succeeds': False,
#    'V_date': False,
#    'V_crazy': False,
#    'V_crush': False,
#    'V_contemporary': False,
#    'V_stylish': False,
#    'V_road': False,
#    'V_pleasant': False,
#    'V_sets': False,
#    'V_extreme': False,
#    'V_amount': False,
#    'V_casting': False,
#    'V_pacing': False,
#    'V_finds': False,
#    'V_attempts': False,
#    'V_money': False,
#    'V_twists': False,
#    'V_thinking': False,
#    'V_ones': False,
#    'V_grace': False,
#    'V_george': False,
#    'V_involved': False,
#    'V_forgettable': False,
#    'V_leads': False,
#    'V_tragic': False,
#    'V_five': False,
#    'V_intimate': False,
#    'V_largely': False,
#    'V_joke': False,
#    'V_course': False,
#    'V_episode': False,
#    'V_focus': False,
#    'V_stars': False,
#    'V_uneven': False,
#    'V_indeed': False,
#    'V_gripping': False,
#    'V_inventive': False,
#    'V_old-fashioned': False,
#    'V_plain': False,
#    'V_trouble': False,
#    'V_living': False,
#    'V_treat': False,
#    'V_e': False,
#    'V_steven': False,
#    'V_mix': False,
#    'V_grant': False,
#    'V_happy': False,
#    'V_recommend': False,
#    'V_unique': False,
#    'V_missing': False,
#    'V_absolutely': False,
#    'V_williams': False,
#    'V_runs': False,
#    'V_presents': False,
#    'V_complete': False,
#    'V_happens': False,
#    'V_successful': False,
#    'V_york': False,
#    'V_es': False,
#    'V_masterpiece': False,
#    'V_drag': False,
#    'V_called': False,
#    'V_disturbing': False,
#    'V_promise': False,
#    'V_colorful': False,
#    'V_soundtrack': False,
#    'V_considerable': False,
#    'V_goofy': False,
#    'V_themes': False,
#    'V_painful': False,
#    'V_appears': False,
#    'V_involving': False,
#    'V_heaven': False,
#    'V_badly': False,
#    'V_poetry': False,
#    'V_friendship': False,
#    'V_business': False,
#    'V_substance': False,
#    'V_problems': False,
#    'V_water': False,
#    "V_we've": False,
#    'V_couple': False,
#    'V_blend': False,
#    'V_politics': False,
#    'V_originality': False,
#    'V_forget': False,
#    'V_british': False,
#    'V_typical': False,
#    'V_pieces': False,
#    'V_viewing': False,
#    "V_man's": False,
#    'V_hits': False,
#    'V_wanted': False,
#    'V_person': False,
#    'V_effect': False,
#    'V_bizarre': False,
#    'V_sentimentality': False,
#    'V_urban': False,
#    'V_share': False,
#    'V_target': False,
#    'V_bright': False,
#    'V_evil': False,
#    'V_parts': False,
#    'V_manner': False,
#    'V_gay': False,
#    'V_situations': False,
#    'V_meditation': False,
#    'V_strangely': False,
#    'V_skin': False,
#    'V_mean': False,
#    'V_flicks': False,
#    'V_triumph': False,
#    'V_tom': False,
#    'V_played': False,
#    'V_refreshing': False,
#    'V_oscar': False,
#    'V_loses': False,
#    'V_equally': False,
#    'V_interested': False,
#    'V_terrible': False,
#    'V_forced': False,
#    'V_[a]': False,
#    'V_soul': False,
#    'V_imax': False,
#    'V_somehow': False,
#    'V_absorbing': False,
#    'V_central': False,
#    'V_clichés': False,
#    'V_haunting': False,
#    'V_average': False,
#    "V_director's": False,
#    'V_energetic': False,
#    'V_understand': False,
#    'V_sexy': False,
#    'V_derivative': False,
#    'V_conflict': False,
#    'V_fan': False,
#    'V_alive': False,
#    'V_doubt': False,
#    'V_sophisticated': False,
#    'V_virtually': False,
#    'V_fare': False,
#    'V_report': False,
#    'V_created': False,
#    'V_general': False,
#    'V_well-acted': False,
#    'V_standard': False,
#    'V_said': False,
#    'V_jackson': False,
#    'V_lame': False,
#    'V_company': False,
#    'V_obviously': False,
#    'V_tells': False,
#    'V_fast': False,
#    'V_loss': False,
#    'V_questions': False,
#    'V_means': False,
#    'V_el': False,
#    'V_miss': False,
#    'V_eventually': False,
#    'V_painfully': False,
#    'V_television': False,
#    'V_name': False,
#    'V_night': False,
#    'V_90': False,
#    'V_liked': False,
#    'V_hate': False,
#    'V_grief': False,
#    'V_franchise': False,
#    'V_setting': False,
#    'V_whatever': False,
#    'V_somewhere': False,
#    'V_battle': False,
#    'V_monster': False,
#    'V_frame': False,
#    'V_crafted': False,
#    'V_dry': False,
#    'V_please': False,
#    'V_poor': False,
#    'V_twist': False,
#    'V_word': False,
#    'V_dream': False,
#    'V_depressing': False,
#    'V_stunning': False,
#    'V_vivid': False,
#    'V_wedding': False,
#    'V_amazing': False,
#    'V_remarkably': False,
#    'V_ms': False,
#    'V_toward': False,
#    'V_essentially': False,
#    'V_clearly': False,
#    'V_affecting': False,
#    'V_niro': False,
#    'V_fat': False,
#    'V_worthwhile': False,
#    'V_room': False,
#    'V_thought-provoking': False,
#    'V_blue': False,
#    'V_atmosphere': False,
#    'V_sitting': False,
#    'V_generally': False,
#    'V_finish': False,
#    'V_allows': False,
#    'V_let': False,
#    'V_break': False,
#    'V_imaginative': False,
#    'V_insightful': False,
#    'V_possibly': False,
#    'V_white': False,
#    'V_match': False,
#    'V_unlike': False,
#    'V_price': False,
#    'V_places': False,
#    'V_footage': False,
#    'V_lines': False,
#    'V_opportunity': False,
#    'V_conventional': False,
#    'V_inspired': False,
#    'V_una': False,
#    'V_heavy-handed': False,
#    'V_warmth': False,
#    'V_japanese': False,
#    'V_superficial': False,
#    'V_faith': False,
#    'V_brain': False,
#    'V_riveting': False,
#    'V_slapstick': False,
#    'V_treasure': False,
#    'V_edge': False,
#    'V_lets': False,
#    'V_refreshingly': False,
#    'V_popcorn': False,
#    'V_girls': False,
#    'V_boys': False,
#    'V_excitement': False,
#    'V_deliver': False,
#    'V_genuinely': False,
#    'V_red': False,
#    ...},
#   'pos')]

# %% [markdown]
# #### We create the training and test sets, train a Naïve Bayes classifier, and look at the accuracy, and this time we’ll do a 90/10 split of our approximately 10,000 documents.

# %%
train_set, test_set = featuresets_NEW[1000:], featuresets_NEW[:1000]
classifier = nltk.NaiveBayesClassifier.train(train_set)

print (nltk.classify.accuracy(classifier, test_set))
# Out:
# 0.737

# %% [markdown]
# #### The function show_most_informative_features shows the top ranked features according to the ratio of one label to the other one.  For example, if there are 20 times as many positive documents containing this word as negative ones, then the ratio will be reported as     20.00: 1.00   pos:neg.

# %%
classifier.show_most_informative_features(30)
# Out:
# Most Informative Features
#             V_engrossing = True              pos : neg    =     20.8 : 1.0
#                   V_warm = True              pos : neg    =     19.4 : 1.0
#               V_mediocre = True              neg : pos    =     16.5 : 1.0
#                V_routine = True              neg : pos    =     15.2 : 1.0
#                V_generic = True              neg : pos    =     15.2 : 1.0
#              V_inventive = True              pos : neg    =     14.2 : 1.0
#             V_refreshing = True              pos : neg    =     13.5 : 1.0
#                 V_boring = True              neg : pos    =     13.4 : 1.0
#                     V_90 = True              neg : pos    =     13.2 : 1.0
#              V_wonderful = True              pos : neg    =     12.5 : 1.0
#                   V_flat = True              neg : pos    =     12.3 : 1.0
#           V_refreshingly = True              pos : neg    =     12.2 : 1.0
#                 V_stupid = True              neg : pos    =     11.5 : 1.0
#               V_touching = True              pos : neg    =     11.4 : 1.0
#               V_captures = True              pos : neg    =     11.3 : 1.0
#                  V_stale = True              neg : pos    =     11.1 : 1.0
#            V_mesmerizing = True              pos : neg    =     10.9 : 1.0
#                 V_beauty = True              pos : neg    =     10.5 : 1.0
#                 V_dreary = True              neg : pos    =     10.5 : 1.0
#              V_realistic = True              pos : neg    =     10.2 : 1.0
#               V_provides = True              pos : neg    =     10.1 : 1.0
#                   V_loud = True              neg : pos    =      9.9 : 1.0
#             V_meandering = True              neg : pos    =      9.8 : 1.0
#               V_tiresome = True              neg : pos    =      9.8 : 1.0
#               V_annoying = True              neg : pos    =      9.8 : 1.0
#                   V_dull = True              neg : pos    =      9.7 : 1.0
#            V_examination = True              pos : neg    =      9.7 : 1.0
#                V_intense = True              pos : neg    =      9.6 : 1.0
#                 V_tender = True              pos : neg    =      9.6 : 1.0
#               V_powerful = True              pos : neg    =      9.1 : 1.0

# %% [markdown]
# # Adding to Sentiment Lexicon:  Subjectivity Count features

# %%
def SL_features_NEW(document, SL):
    document_words = set(document)
    features = {}
    for word in new_word_features:
        features['contains(%s)' % word] = (word in document_words)
        # count variables for the 4 classes of subjectivity
        weakPos = 0
        strongPos = 0
        weakNeg = 0
        strongNeg = 0
        for word in document_words:
            if word in SL:
                strength, posTag, isStemmed, polarity = SL[word]
                if strength == 'weaksubj' and polarity == 'positive':
                    weakPos += 1
                if strength == 'strongsubj' and polarity == 'positive':
                    strongPos += 1
                if strength == 'weaksubj' and polarity == 'negative':
                    weakNeg += 1
                if strength == 'strongsubj' and polarity == 'negative':
                    strongNeg += 1
                features['positivecount'] = weakPos + (2 * strongPos)
                features['negativecount'] = weakNeg + (2 * strongNeg)      
    return features

# %%
SL_featuresets_NEW = [(SL_features_NEW(d, SL), c) for (d,c) in documents]

# %%
len(SL_featuresets_NEW)
# Out:
# 10662

# %% [markdown]
# #### We create the training and test sets, train a Naïve Bayes classifier, and look at the accuracy, and this time we’ll do a 90/10 split of our approximately 10,000 documents.

# %%
train_set, test_set = SL_featuresets_NEW[1000:], SL_featuresets_NEW[:1000]
classifier = nltk.NaiveBayesClassifier.train(train_set)
print(nltk.classify.accuracy(classifier, test_set))
# Out:
# 0.747

# %% [markdown]
# #### The function show_most_informative_features shows the top ranked features according to the ratio of one label to the other one.  For example, if there are 20 times as many positive documents containing this word as negative ones, then the ratio will be reported as     20.00: 1.00   pos:neg.

# %%
classifier.show_most_informative_features(30)

# %% [markdown]
# # Adding to Negation Features

# %%
def NOT_features_NEW(document, new_word_features, negationwords):
    features = {}
    for word in new_word_features:
        features['V_{}'.format(word)] = False
        features['V_NOT{}'.format(word)] = False
    # go through document words in order
    for i in range(0, len(document)):
        word = document[i]
        if ((i + 1) < len(document)) and ((word in negationwords) or (word.endswith("n't"))):
            i += 1
            features['V_{}'.format(document[i])] = (document[i] in new_word_features)
        else:
            features['V_NOT{}'.format(word)] = (word in new_word_features)
    return features

# %%
NOT_featuresets_NEW = [(NOT_features_NEW(d, new_word_features, negationwords), c) for (d, c) in documents]
print(NOT_featuresets_NEW[0][0]['V_NOTcare'])
print(NOT_featuresets_NEW[0][0]['V_always'])
# Out:
# False
# False

# %% [markdown]
# #### We create the training and test sets, train a Naïve Bayes classifier, and look at the accuracy, and this time we’ll do a 90/10 split of our approximately 10,000 documents.

# %%
train_set, test_set = NOT_featuresets_NEW[1000:], NOT_featuresets_NEW[:1000]
classifier = nltk.NaiveBayesClassifier.train(train_set)
print (nltk.classify.accuracy(classifier, test_set))
# Out:
# 0.786

# %% [markdown]
# #### The function show_most_informative_features shows the top ranked features according to the ratio of one label to the other one.  For example, if there are 20 times as many positive documents containing this word as negative ones, then the ratio will be reported as     20.00: 1.00   pos:neg.

# %%
classifier.show_most_informative_features(30)
# Out:
# Most Informative Features
#          V_NOTengrossing = True              pos : neg    =     20.8 : 1.0
#                V_NOTwarm = True              pos : neg    =     19.4 : 1.0
#            V_NOTmediocre = True              neg : pos    =     16.5 : 1.0
#             V_NOTgeneric = True              neg : pos    =     15.2 : 1.0
#             V_NOTroutine = True              neg : pos    =     15.2 : 1.0
#           V_NOTinventive = True              pos : neg    =     14.2 : 1.0
#          V_NOTrefreshing = True              pos : neg    =     13.5 : 1.0
#              V_NOTboring = True              neg : pos    =     13.4 : 1.0
#                  V_NOT90 = True              neg : pos    =     13.2 : 1.0
#           V_NOTwonderful = True              pos : neg    =     12.5 : 1.0
#                V_NOTflat = True              neg : pos    =     12.3 : 1.0
#        V_NOTrefreshingly = True              pos : neg    =     12.2 : 1.0
#              V_NOTstupid = True              neg : pos    =     11.5 : 1.0
#            V_NOTtouching = True              pos : neg    =     11.4 : 1.0
#            V_NOTcaptures = True              pos : neg    =     11.3 : 1.0
#               V_NOTstale = True              neg : pos    =     11.1 : 1.0
#                 V_enough = True              neg : pos    =     11.1 : 1.0
#         V_NOTmesmerizing = True              pos : neg    =     10.9 : 1.0
#              V_NOTbeauty = True              pos : neg    =     10.5 : 1.0
#              V_NOTdreary = True              neg : pos    =     10.5 : 1.0
#           V_NOTrealistic = True              pos : neg    =     10.2 : 1.0
#            V_NOTprovides = True              pos : neg    =     10.1 : 1.0
#                V_NOTloud = True              neg : pos    =      9.9 : 1.0
#            V_NOTtiresome = True              neg : pos    =      9.8 : 1.0
#            V_NOTannoying = True              neg : pos    =      9.8 : 1.0
#          V_NOTmeandering = True              neg : pos    =      9.8 : 1.0
#                V_NOTdull = True              neg : pos    =      9.7 : 1.0
#         V_NOTexamination = True              pos : neg    =      9.7 : 1.0
#              V_NOTtender = True              pos : neg    =      9.6 : 1.0
#             V_NOTintense = True              pos : neg    =      9.6 : 1.0
